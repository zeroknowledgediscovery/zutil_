# %%
import numpy as np
import time
from scipy.spatial import distance_matrix
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import scipy.stats as stats
import glob

# %% [markdown]
# ## Genearte random classes
# ../gen_dataset.sh will generate 100 classes (25 sequences, with 2000 bits long) and save in the ../seqDatasets folder, then we can concatenate two random classes to for a bi-classification dataset;
# - the parameters (number of classes, number of sequences, sequence length can be modified in ../gen_dataset.sh)
# - more parameters could be changed (see manual of llk_baseChoice by using -h)
# - that is where I have to use sleep(1).

# %% [raw]
# # no need to re-run it unless you want a new set of classes or you want to change parameters.
# ! ../gen_dataset.sh

# %% [markdown]
# ## define the separation measurement. Return both the ratio and between-class distance.

# %%
def separation(D, labels):
    dim = len(D)
    A, B = 0, 0
    ca, cb = 0, 0
    for i in range(dim):
        for j in range(dim):
            k, l = labels[i], labels[j]
            if k == l:
                A += D[i][j]
                ca += 1
            else:
                B += D[i][j]
                cb += 1
    r = (A / ca) / (B / cb)
    return r, B # return both ratio (r) and between-class distance (B)

#------------------------------A test of validity--------------------------
# n1, n2 = 5, 5
# std1, std2 = .2, .2 # the smaller the stds the smaller the separation 
# labels = [0] * n1 + [1] * n2
# X1 = np.array([-1, -1]) + std1 * np.random.randn(n1, 2)
# X2 = np.array([1, 1]) + std2 * np.random.randn(n2, 2)
# X = np.vstack((X1, X2))
# D = distance_matrix(X, X)
# r, B = separation(D, labels)
# print('ratio = {}, between-class distance = {}'.format(r, B))

# %% [markdown]
# ## Generate random base PFSA projectors
# - user defined PFSA cfg files are saved to ../baseChoice_cfgfiles

# %%
num_random_pfsa = 4
num_states_min, num_states_max = 2, 5
for i in range(num_random_pfsa):
    num_states = num_states_min + np.random.randint((num_states_max + 1 - num_states_min))
    ! ../genRandPFSA -a 2 -n {num_states} -p ../baseChoice_cfgfiles/PFSA_{i}.cfg
    time.sleep(1) # Node that I also have to use sleep here or otherwise we will have all the same PFSA

# %% [markdown]
# ## Form bi-classification datasets and compare
# - choose two classes randomly and concatenate the sequence files.
# - run both the default lsmash and lsmash with user defined base PFSA
# - save both ratio and between-class distance for plotting

# %%
labels = [0] * 25 + [1] * 25
num_runs = 200

r_lsmash, r_random = [], [] # the ratio (mean within-class distance) / (mean between-class distance)
B_lsmash, B_random = [], [] # the total between-class distance

for n in range(num_runs):
    i = np.random.randint(100) + 1
    j = np.random.randint(100) + 1

    ! cat ../seqDatasets/seq_{i}.dat ../seqDatasets/seq_{j}.dat > seq.dat
    
    # default four PFSA
    ! ../lsmash -f seq.dat -T symbolic -o lsmash.dst -S 0
    dist_lsmash = np.genfromtxt('lsmash.dst')
    r, B = separation(dist_lsmash, labels)
    r_lsmash.append(r)
    B_lsmash.append(B)
    
    # randomly generated base PFSA
    cmd = '../lsmash -f seq.dat -T symbolic -o random.dst -S 0 -F {}'.format(' '.join(glob.glob('../baseChoice_cfgfiles/*')))
    ! {cmd}
    dist_random = np.genfromtxt('random.dst')
    r, B = separation(dist_random, labels)
    r_random.append(r)
    B_random.append(B)

    print('round {}, ({}, {}), lsmash = {}, random={}'.format(n, i, j, r_lsmash[n], r_random[n]))
# Out:
# round 0, (12, 6), lsmash = 0.19259832413728392, random=0.13235431964106545
# round 1, (40, 42), lsmash = 0.2893519622507745, random=0.22579044234302914
# round 2, (98, 20), lsmash = 0.1688194086634755, random=0.08786554755389196
# round 3, (23, 12), lsmash = 0.20241077562165208, random=0.15280935819349717
# round 4, (79, 66), lsmash = 0.16865271301076656, random=0.062329405622480995
# round 5, (50, 38), lsmash = 0.5576953396712698, random=0.38672403691003127
# round 6, (69, 43), lsmash = 0.1813001270048855, random=0.1263611961574055
# round 7, (76, 28), lsmash = 0.42265393007492413, random=0.09848718262746466
# round 8, (73, 67), lsmash = 0.2327945852457941, random=0.19758743723771735
# round 9, (8, 81), lsmash = 0.16163242712532153, random=0.08620928758812886
# round 10, (14, 78), lsmash = 0.08969656385989104, random=0.06319841036156888
# round 11, (91, 70), lsmash = 0.17437435229198603, random=0.1183313146395715
# round 12, (69, 46), lsmash = 0.20476024276483112, random=0.05359330156577908
# round 13, (68, 5), lsmash = 0.8220057044948716, random=0.37891129939543067
# round 14, (96, 88), lsmash = 0.15265666413543003, random=0.09906088045053564
# round 15, (3, 84), lsmash = 0.17395613816205843, random=0.09064060986161578
# round 16, (4, 84), lsmash = 0.36584233587904147, random=0.18266557146530127
# round 17, (61, 44), lsmash = 0.18667028493164967, random=0.25933125249978606
# round 18, (48, 67), lsmash = 0.11099864605672259, random=0.3980679265056469
# round 19, (73, 79), lsmash = 0.13727720953080108, random=0.06376730654501486
# round 20, (60, 96), lsmash = 0.4260817702040708, random=0.4428501034711455
# round 21, (16, 41), lsmash = 0.6682216497373192, random=0.43170705574770135
# round 22, (10, 19), lsmash = 0.9138440221104723, random=0.4407872547591746
# round 23, (32, 65), lsmash = 0.47379216461452234, random=0.6143641215533866
# round 24, (71, 27), lsmash = 0.1857981966512054, random=0.22976066192343303
# round 25, (39, 81), lsmash = 0.15076360461461957, random=0.08947881410407621
# round 26, (7, 48), lsmash = 0.13714618976597745, random=0.15493216225085
# round 27, (5, 4), lsmash = 0.22242766612158243, random=0.2051604194905588
# round 28, (31, 50), lsmash = 0.2787946255722713, random=0.33007697561258725
# round 29, (81, 57), lsmash = 0.21908177120805333, random=0.20538983066214245
# round 30, (92, 24), lsmash = 0.16289761828124977, random=0.10088614514766593
# round 31, (97, 43), lsmash = 0.5460029374856897, random=0.40986994324499804
# round 32, (18, 29), lsmash = 0.4091735544284111, random=0.222568934277408
# round 33, (1, 19), lsmash = 0.8100212225561565, random=0.6505207148980178
# round 34, (92, 91), lsmash = 0.25163729444884025, random=0.3449572179903536
# round 35, (75, 34), lsmash = 0.12142267841031061, random=0.12431433823617652
# round 36, (35, 3), lsmash = 0.11702267899738834, random=0.14883993899762085
# round 37, (75, 75), lsmash = 1.0, random=1.0
# round 38, (47, 41), lsmash = 0.32909653241169634, random=0.25070783107594824
# round 39, (44, 2), lsmash = 0.186511828995205, random=0.11894869332250196
# round 40, (42, 61), lsmash = 0.17490625528847067, random=0.17222206092841946
# round 41, (11, 48), lsmash = 0.13419035422619313, random=0.10276303905044726
# round 42, (36, 55), lsmash = 0.24085744562926575, random=0.2993903339338507
# round 43, (44, 25), lsmash = 0.4333211951919609, random=0.2115185375832671
# round 44, (38, 88), lsmash = 0.15447179959049323, random=0.09658531805377489
# round 45, (93, 83), lsmash = 0.1839155464313125, random=0.14989962554575137
# round 46, (24, 19), lsmash = 0.7161655545996056, random=0.20955770235563723
# round 47, (85, 49), lsmash = 0.13526563538725941, random=0.05050844161650451
# round 48, (51, 32), lsmash = 0.14787607323037125, random=0.09053670915139499
# round 49, (61, 24), lsmash = 0.1686159340386592, random=0.20257423766214278
# round 50, (37, 71), lsmash = 0.09759641369486209, random=0.14985086849459772
# round 51, (99, 44), lsmash = 0.2932089680048081, random=0.15683423510613684
# round 52, (57, 60), lsmash = 0.2654424051036368, random=0.3936429341939091
# round 53, (4, 27), lsmash = 0.22228771407897002, random=0.189469808456933
# round 54, (57, 96), lsmash = 0.5744794782365483, random=0.39459374528027064
# round 55, (95, 88), lsmash = 0.21020646788816844, random=0.10095862447159915
# round 56, (80, 47), lsmash = 0.3810033670482247, random=0.11660254886856336
# round 57, (47, 8), lsmash = 0.24290856253697068, random=0.06814442591067664
# round 58, (53, 63), lsmash = 0.4664527181070848, random=0.09610681543743936
# round 59, (8, 78), lsmash = 0.2105650321850543, random=0.048651672062957715
# round 60, (54, 44), lsmash = 0.9237635790697108, random=0.5169892044875389
# round 61, (12, 19), lsmash = 0.2072713692577643, random=0.19977545543794797
# round 62, (23, 51), lsmash = 0.14324823609507104, random=0.12305842883058969
# round 63, (50, 1), lsmash = 0.6401555698940214, random=0.4970777517599203
# round 64, (34, 60), lsmash = 0.20111853195839288, random=0.24138017148394664
# round 65, (26, 83), lsmash = 0.061030668501365876, random=0.06672448102599508
# round 66, (10, 78), lsmash = 0.17242866535907037, random=0.06370552744401115
# round 67, (85, 72), lsmash = 0.1074179411390841, random=0.06383936657824578
# round 68, (37, 59), lsmash = 0.20816555570414633, random=0.09526892763060607
# round 69, (74, 82), lsmash = 0.20160322478520312, random=0.2103894180722015
# round 70, (82, 46), lsmash = 0.3397788985775705, random=0.15283431130378472
# round 71, (41, 88), lsmash = 0.16733886710759158, random=0.11926906388643098
# round 72, (78, 35), lsmash = 0.15439313903797672, random=0.0996902135413407
# round 73, (93, 45), lsmash = 0.13961271510036355, random=0.10052846904947968
# round 74, (8, 59), lsmash = 0.1849702381312678, random=0.04758131661227611
# round 75, (76, 35), lsmash = 0.2616278055559488, random=0.1046994034036229
# round 76, (50, 1), lsmash = 0.6401555698940214, random=0.4970777517599203
# round 77, (15, 3), lsmash = 0.5524256759559538, random=0.25359764728721873
# round 78, (35, 40), lsmash = 0.17195860844338176, random=0.1893891576621474
# round 79, (23, 30), lsmash = 0.13167496912570698, random=0.07842990066135343
# round 80, (43, 24), lsmash = 0.8498204359064225, random=0.7750111696656905
# round 81, (57, 63), lsmash = 0.24173768258684777, random=0.29962411471985834
# round 82, (24, 6), lsmash = 0.672811817570779, random=0.09765215888392688
# round 83, (24, 5), lsmash = 0.5653960752842351, random=0.35438133421754586
# round 84, (81, 80), lsmash = 0.3907819358200124, random=0.17920386813036948
# round 85, (23, 7), lsmash = 0.3988481750665967, random=0.1544956153090796
# round 86, (23, 58), lsmash = 0.4821622860109871, random=0.3385018069974841
# round 87, (31, 57), lsmash = 0.1752324258684364, random=0.14250837558246013
# round 88, (44, 33), lsmash = 0.2812115658724316, random=0.40854406647509384
# round 89, (53, 89), lsmash = 0.11347762022589193, random=0.08729441830652016
# round 90, (15, 40), lsmash = 0.5780194364894001, random=0.17445677926166617
# round 91, (52, 67), lsmash = 0.09392013308998337, random=0.10543568324637975
# round 92, (50, 3), lsmash = 0.3328545394601637, random=0.34630317005865124
# round 93, (79, 64), lsmash = 0.13902860510339862, random=0.057315660368089605
# round 94, (12, 28), lsmash = 0.20279150408215518, random=0.1530249143048995
# round 95, (17, 46), lsmash = 0.12710956149549751, random=0.10461859354602808
# round 96, (11, 94), lsmash = 0.14661017745564683, random=0.09984417261424758
# round 97, (61, 42), lsmash = 0.17490625528847079, random=0.1722220609284189
# round 98, (81, 55), lsmash = 0.13190656945193385, random=0.17161828052491046
# round 99, (35, 48), lsmash = 0.12189178731864124, random=0.42104834431551985
# round 100, (39, 10), lsmash = 0.13774004550204372, random=0.060131133140629456
# round 101, (63, 8), lsmash = 0.2653471337604967, random=0.18295951479678177
# round 102, (66, 97), lsmash = 0.6702620300987954, random=0.08932833520267335
# round 103, (86, 49), lsmash = 0.2822371944192666, random=0.19735872639991808
# round 104, (58, 95), lsmash = 0.4559379969168169, random=0.49095351026711015
# round 105, (74, 4), lsmash = 0.5249381423409192, random=0.1511740583926833
# round 106, (18, 40), lsmash = 0.6781758380693745, random=0.11067047285760861
# round 107, (11, 87), lsmash = 0.17127870675653634, random=0.15794774286303592
# round 108, (28, 22), lsmash = 0.11334441432383441, random=0.1250967750456528
# round 109, (8, 25), lsmash = 0.1491098158017579, random=0.17427838407038224
# round 110, (20, 29), lsmash = 0.3237597147219993, random=0.2225026766964744
# round 111, (93, 61), lsmash = 0.19128462296763918, random=0.16007248800116816
# round 112, (60, 37), lsmash = 0.2889230063890538, random=0.39362797381791
# round 113, (41, 58), lsmash = 0.8183311033215648, random=0.6166524084113126
# round 114, (28, 95), lsmash = 0.49248905961689277, random=0.2979143840222415
# round 115, (94, 36), lsmash = 0.7284187961754208, random=0.3723492855776596
# round 116, (46, 93), lsmash = 0.2257718706036531, random=0.25300114057280815
# round 117, (86, 86), lsmash = 1.0, random=1.0
# round 118, (25, 65), lsmash = 0.17070393578854112, random=0.2245223354700561
# round 119, (99, 62), lsmash = 0.0876731022090115, random=0.07247252537457397
# round 120, (87, 19), lsmash = 0.6920060960363864, random=0.5490174286094524
# round 121, (48, 72), lsmash = 0.128636051897587, random=0.1923473400465137
# round 122, (20, 90), lsmash = 0.20246094331581793, random=0.07429430150490815
# round 123, (59, 43), lsmash = 0.16776655478087318, random=0.10285897914746685
# round 124, (20, 96), lsmash = 0.635122796415045, random=0.2372320973384141
# round 125, (88, 85), lsmash = 0.15438987395095663, random=0.21471197179239196
# round 126, (88, 65), lsmash = 0.24676685159994974, random=0.09444501718445665
# round 127, (34, 73), lsmash = 0.259320810321496, random=0.18575719565577117
# round 128, (37, 12), lsmash = 0.2972653851730766, random=0.23117818103003693
# round 129, (35, 63), lsmash = 0.2274242793553533, random=0.176504659299091
# round 130, (48, 23), lsmash = 0.16860372143894942, random=0.36044284101231394
# round 131, (26, 24), lsmash = 0.08246572455333431, random=0.09017831472206031
# round 132, (47, 10), lsmash = 0.42611836910708806, random=0.1056976061229458
# round 133, (17, 72), lsmash = 0.6903756972492149, random=0.513433143409195
# round 134, (82, 71), lsmash = 0.1019891444104526, random=0.1520295122914088
# round 135, (49, 1), lsmash = 0.3525111036507973, random=0.1511643536454469
# round 136, (3, 42), lsmash = 0.8020130100343027, random=0.6245316093672928
# round 137, (8, 80), lsmash = 0.19581582661860042, random=0.14623417675136632
# round 138, (86, 75), lsmash = 0.16100444806216974, random=0.1415812794531557
# round 139, (36, 11), lsmash = 0.14863447601882612, random=0.1254809099486434
# round 140, (92, 66), lsmash = 0.2196177674971152, random=0.2962539558631109
# round 141, (89, 14), lsmash = 0.06620226612968194, random=0.044944650341715194
# round 142, (77, 53), lsmash = 0.1492148190320907, random=0.18231167863050293
# round 143, (11, 41), lsmash = 0.18870278141901234, random=0.10627076867785382
# round 144, (8, 11), lsmash = 0.8497624986967094, random=0.73213991632412
# round 145, (43, 66), lsmash = 0.8401419954646032, random=0.11065652468813084
# round 146, (89, 68), lsmash = 0.08615573433174882, random=0.05105160905528218
# round 147, (33, 9), lsmash = 0.2864029343027041, random=0.4138249838429962
# round 148, (67, 83), lsmash = 0.16994396788300303, random=0.22436051329582557
# round 149, (27, 96), lsmash = 0.8500134395385215, random=0.8934512493806488
# round 150, (52, 77), lsmash = 0.06322240748914632, random=0.06856437947640708
# round 151, (82, 58), lsmash = 0.19619567233341137, random=0.24909031920776917
# round 152, (47, 21), lsmash = 0.07191584671910749, random=0.05686296115160774
# round 153, (2, 37), lsmash = 0.15474675662493187, random=0.17302830901293362
# round 154, (56, 25), lsmash = 0.6457662624661888, random=0.10286010684004557
# round 155, (77, 66), lsmash = 0.16523331358953422, random=0.11833219193977783
# round 156, (95, 49), lsmash = 0.39768820358759627, random=0.13963711405001533
# round 157, (2, 16), lsmash = 0.1756812244327224, random=0.15114177753547298
# round 158, (37, 84), lsmash = 0.49291660277542576, random=0.10807940664572128
# round 159, (4, 27), lsmash = 0.22228771407897002, random=0.189469808456933
# round 160, (50, 63), lsmash = 0.6533097219466615, random=0.20250807382112615
# round 161, (94, 21), lsmash = 0.061203970215282226, random=0.06394150970750415
# round 162, (51, 41), lsmash = 0.12476367851753033, random=0.10957918015522848
# round 163, (92, 87), lsmash = 0.13459841482511092, random=0.16486925065276162
# round 164, (72, 83), lsmash = 0.13248641318554968, random=0.12613883591351624
# round 165, (97, 61), lsmash = 0.12841612782688358, random=0.13471209250411115
# round 166, (86, 2), lsmash = 0.1725718873202764, random=0.11041405160506788
# round 167, (26, 8), lsmash = 0.06624183203781062, random=0.059108001252515335
# round 168, (81, 53), lsmash = 0.3263382788413243, random=0.19683115977106527
# round 169, (30, 73), lsmash = 0.14321716417664124, random=0.14015837913717644
# round 170, (94, 71), lsmash = 0.3371305083224437, random=0.6026394790817197
# round 171, (28, 48), lsmash = 0.16428365955393678, random=0.32104570897286283
# round 172, (73, 60), lsmash = 0.7281799867997752, random=0.28930731791445863
# round 173, (23, 99), lsmash = 0.2213707164411444, random=0.2230534847972422
# round 174, (21, 13), lsmash = 0.06967219039936015, random=0.06033959067440697
# round 175, (6, 66), lsmash = 0.5802661041700867, random=0.7699432321728596
# round 176, (91, 100), lsmash = 0.34825675739177264, random=0.14623103005178834
# round 177, (42, 78), lsmash = 0.13086044607069686, random=0.07797761324298211
# round 178, (70, 76), lsmash = 0.177492475600887, random=0.11437022458294495
# round 179, (40, 38), lsmash = 0.606138579600918, random=0.20283322507488685
# round 180, (49, 79), lsmash = 0.1501098388874326, random=0.05583357648147214
# round 181, (16, 54), lsmash = 0.8573520842614877, random=0.3228375571959845
# round 182, (83, 30), lsmash = 0.27335937012921135, random=0.11909470646466638
# round 183, (67, 56), lsmash = 0.13756156731603314, random=0.18310192066362774
# round 184, (93, 19), lsmash = 0.8659898948274525, random=0.2957802439916776
# round 185, (4, 37), lsmash = 0.25776133474982266, random=0.2303169839427953
# round 186, (68, 49), lsmash = 0.305041133478671, random=0.18216787099873283
# round 187, (26, 35), lsmash = 0.05892687292246903, random=0.07033932523478253
# round 188, (36, 60), lsmash = 0.3075854842062423, random=0.373103222308537
# round 189, (98, 7), lsmash = 0.1357729568680397, random=0.09088367985230714
# round 190, (87, 61), lsmash = 0.18998875551616096, random=0.2129505403476825
# round 191, (64, 38), lsmash = 0.5773887476414817, random=0.19609652066250255
# round 192, (93, 73), lsmash = 0.8908016687084449, random=0.6834089191844344
# round 193, (15, 13), lsmash = 0.4577497548373679, random=0.19309947038848524
# round 194, (9, 13), lsmash = 0.46834725239622377, random=0.21250848624187563
# round 195, (55, 56), lsmash = 0.31986483388173215, random=0.19945817514321768
# round 196, (74, 36), lsmash = 0.21179167451438388, random=0.13495606940881524
# round 197, (19, 94), lsmash = 0.3999992755211187, random=0.320725557540164
# round 198, (85, 25), lsmash = 0.11655338023621525, random=0.052234804816876236
# round 199, (80, 23), lsmash = 0.6442193674838297, random=0.15537612693464303

# %% [markdown]
# ## Histograms

# %%
plt.figure()
ax = sns.distplot(B_lsmash, bins=15, label='default')
ax.axvline(np.mean(B_lsmash), color='blue')
sns.distplot(B_random, bins=15, label='user defined')
ax.axvline(np.mean(B_random), color='green')
plt.legend(fontsize=15)
plt.title('Between class distance', fontsize=20)
plt.show()

# %%
plt.figure()
ax = sns.distplot(r_lsmash, bins=15, label='default')
ax.axvline(np.mean(r_lsmash), color='blue')
sns.distplot(r_random, bins=15, label='user defined')
ax.axvline(np.mean(r_random), color='green')
plt.legend(fontsize=15)
plt.title('SAE ratio', fontsize=20)
plt.show()

# %%
def experiment(num_random_pfsa=4, num_datasets=100):
    # Generate random projector
    num_states_min, num_states_max = 2, 5
    for i in range(num_random_pfsa):
        num_states = num_states_min + np.random.randint((num_states_max + 1 - num_states_min))
        ! ../genRandPFSA -a 2 -n {num_states} -p ../baseChoice_cfgfiles/PFSA_{i}.cfg
        time.sleep(1) # Node that I also have to use sleep here or otherwise we will have all the same PFSA

    # compare the between-class distance of randomly generated projector base set with the default
    labels = [0] * 25 + [1] * 25

    r_lsmash, r_random = [], [] # the ratio (mean within-class distance) / (mean between-class distance)
    B_lsmash, B_random = [], [] # the total between-class distance

    n = 0
    while n < num_datasets:
        i = np.random.randint(100) + 1
        j = np.random.randint(100) + 1
        if i == j:
            continue
        else:    
            ! cat ../seqDatasets/seq_{i}.dat ../seqDatasets/seq_{j}.dat > seq.dat

            # default four PFSA
            ! ../lsmash -f seq.dat -T symbolic -o lsmash.dst -S 0
            dist_lsmash = np.genfromtxt('lsmash.dst')
            r, B = separation(dist_lsmash, labels)
            r_lsmash.append(r)
            B_lsmash.append(B)

            # randomly generated base PFSA
            cmd = '../lsmash -f seq.dat -T symbolic -o random.dst -S 0 -F {}'.format(' '.join(glob.glob('../baseChoice_cfgfiles/*')))
            ! {cmd}
            dist_random = np.genfromtxt('random.dst')
            r, B = separation(dist_random, labels)
            r_random.append(r)
            B_random.append(B)
        
            # print('round {}, ({}, {}), lsmash = {}, random={}'.format(n, i, j, r_lsmash[n], r_random[n]))
            n += 1
    
    return r_lsmash, r_random
# #---------------------------test-----------------------
# r_lsmash, r_random = experiment(4, 10)

# %% [markdown]
# ## Comparing default against randomly generated base sets
# - for each experiment, generate a random PFSA base, and calculate the SAEs for both default and randomly generated base
# - get the mean SAEs for both methods based on 100 (num_datasets) randomly formed bi-class datasets
# - run 100 (num_experiments) rounds of the expermient and plot the histgrams of the mean SAEs.

# %%
num_datasets = 100
num_experiments = 100
lsmash_mean_sae, random_mean_sae = [], [] 
for i in range(num_experiments):
    print('experiment round {}'.format(i))
    r_lsmash, r_random = experiment(4, num_datasets)    
    lsmash_mean_sae.append(np.mean(r_lsmash))
    random_mean_sae.append(np.mean(r_random))
# Out:
# experiment round 0
# round 0, (67, 84), lsmash = 0.26363270426108315, random=0.09801905909445066
# round 1, (42, 8), lsmash = 0.12564189170424286, random=0.057778680188121864
# round 2, (28, 12), lsmash = 0.20279150408215524, random=0.12850263226322237
# round 3, (77, 81), lsmash = 0.1709000727840152, random=0.2654824426323067
# round 4, (62, 31), lsmash = 0.1354782332695151, random=0.08942873967063462
# round 5, (1, 6), lsmash = 0.6286903421304785, random=0.13102462173435567
# round 6, (3, 69), lsmash = 0.1419325774237113, random=0.06338031407338583
# round 7, (78, 25), lsmash = 0.14823455491476475, random=0.04177539900360622
# round 8, (52, 5), lsmash = 0.07602868287814141, random=0.060616596550711804
# round 9, (93, 23), lsmash = 0.7356383335289047, random=0.0961983692348488
# round 10, (88, 47), lsmash = 0.2651750969662, random=0.13837386130598173
# round 11, (95, 78), lsmash = 0.13517515328693175, random=0.06418061918516903
# round 12, (74, 71), lsmash = 0.1212682465373617, random=0.07509286945889165
# round 13, (28, 37), lsmash = 0.24931665376423076, random=0.2741721696665251
# round 14, (51, 97), lsmash = 0.18683377146013602, random=0.22030991736905167
# round 15, (41, 6), lsmash = 0.5313570933851958, random=0.09865295791181652
# round 16, (7, 31), lsmash = 0.21601090121787522, random=0.11933984799646657
# round 17, (70, 29), lsmash = 0.6213986588220495, random=0.4037721924515925
# round 18, (12, 65), lsmash = 0.3933335625960806, random=0.1255300801618654
# round 19, (84, 9), lsmash = 0.28698257959164797, random=0.09795862414025439
# round 20, (22, 20), lsmash = 0.122485154319132, random=0.07643300003665025
# round 21, (20, 62), lsmash = 0.12301511264739526, random=0.11982586698935241
# round 22, (38, 77), lsmash = 0.17230145743768033, random=0.23972557843777503
# round 23, (81, 98), lsmash = 0.156000667833423, random=0.16792556361710523
# round 24, (62, 73), lsmash = 0.12713645561434736, random=0.12947725407770766
# round 25, (29, 26), lsmash = 0.10740716202994822, random=0.09204432051727358
# round 26, (94, 26), lsmash = 0.11666450682012801, random=0.13489385234933335
# round 27, (40, 56), lsmash = 0.3114454110335419, random=0.33799397266862397
# round 28, (88, 89), lsmash = 0.10438903878241791, random=0.10945015819769999
# round 29, (79, 3), lsmash = 0.10992125727183673, random=0.06586531702867908
# round 30, (48, 56), lsmash = 0.1201220108398541, random=0.17430002583338317
# round 31, (32, 72), lsmash = 0.225329097768595, random=0.15561604251458433
# round 32, (93, 29), lsmash = 0.2994873789168168, random=0.14360376007948303
# round 33, (56, 61), lsmash = 0.17229899012152955, random=0.17403753014865098
# round 34, (38, 72), lsmash = 0.6096552184335344, random=0.4797928958811341
# round 35, (34, 62), lsmash = 0.08798766200204457, random=0.07680094821306274
# round 36, (55, 19), lsmash = 0.1780230546317608, random=0.21871810580420933
# round 37, (39, 46), lsmash = 0.167098650233152, random=0.03130259579467865
# round 38, (17, 33), lsmash = 0.7097393902970244, random=0.5636911722910112
# round 39, (69, 50), lsmash = 0.1884176758064224, random=0.07987217989808267
# round 40, (35, 47), lsmash = 0.23440970691138432, random=0.19953397796796093
# round 41, (53, 3), lsmash = 0.20575465835192494, random=0.1028824512476052
# round 42, (62, 64), lsmash = 0.12454771621026535, random=0.14725173496628316
# round 43, (55, 40), lsmash = 0.16121474990172507, random=0.09593413916683677
# round 44, (97, 31), lsmash = 0.4478770218395848, random=0.24438098208593761
# round 45, (76, 8), lsmash = 0.33506519891203523, random=0.23596241286757952
# round 46, (34, 92), lsmash = 0.10227570859697517, random=0.07898040200306651
# round 47, (79, 45), lsmash = 0.07911462171246024, random=0.05030939709030672
# round 48, (4, 73), lsmash = 0.2627648358935141, random=0.24003272926193348
# round 49, (40, 59), lsmash = 0.16239274587419725, random=0.07796034848548176
# round 50, (46, 4), lsmash = 0.31188982846965607, random=0.0981111926834512
# round 51, (63, 77), lsmash = 0.1475812402694585, random=0.1324477360871976
# round 52, (77, 1), lsmash = 0.1736822667820521, random=0.25424075762922504
# round 53, (97, 14), lsmash = 0.11594429551052528, random=0.07853489323503421
# round 54, (5, 25), lsmash = 0.4688932370323279, random=0.11629916824902856
# round 55, (80, 21), lsmash = 0.06990031014986657, random=0.05308728760382065
# round 56, (64, 50), lsmash = 0.7380645008691316, random=0.10234760018781532
# round 57, (7, 93), lsmash = 0.5092206941812119, random=0.27926744085395633
# round 58, (87, 81), lsmash = 0.30439214236681383, random=0.13692541004267725
# round 59, (46, 47), lsmash = 0.25820652615688217, random=0.048101629862843547
# round 60, (83, 37), lsmash = 0.5237491963178652, random=0.1713648858589787
# round 61, (39, 50), lsmash = 0.15509280860982788, random=0.06613500965820873
# round 62, (54, 28), lsmash = 0.7687304280675831, random=0.24185895475037994
# round 63, (41, 30), lsmash = 0.12709933863549885, random=0.05856895721257971
# round 64, (89, 38), lsmash = 0.08765228984104045, random=0.04491740847213377
# round 65, (23, 7), lsmash = 0.3988481750665967, random=0.1132256706043279
# round 66, (58, 92), lsmash = 0.1435626007645631, random=0.09520233994788464
# round 67, (51, 98), lsmash = 0.10786107082933571, random=0.20463903701024194
# round 68, (25, 69), lsmash = 0.15364644095938174, random=0.04380552959784315
# round 69, (32, 20), lsmash = 0.3872123987483544, random=0.4479544732728027
# round 70, (27, 97), lsmash = 0.35095194992372303, random=0.1430166712489306
# round 71, (48, 7), lsmash = 0.1371461897659779, random=0.11588960603214117
# round 72, (96, 49), lsmash = 0.30860880189961193, random=0.10018557394545019
# round 73, (58, 3), lsmash = 0.5560942559233268, random=0.30726399184087155
# round 74, (79, 63), lsmash = 0.1417860944798727, random=0.05834753940898652
# round 75, (85, 32), lsmash = 0.13007336452748297, random=0.05136960480874457
# round 76, (72, 32), lsmash = 0.22532909776859494, random=0.15561604251458444
# round 77, (82, 9), lsmash = 0.20878081313885824, random=0.28124439678897695
# round 78, (99, 21), lsmash = 0.05459963945166252, random=0.03321302789623897
# round 79, (57, 59), lsmash = 0.13312567177705437, random=0.047245808647026544
# round 80, (74, 4), lsmash = 0.5249381423409192, random=0.14024359511222517
# round 81, (37, 33), lsmash = 0.12396430296220043, random=0.1568053196104604
# round 82, (38, 20), lsmash = 0.6391589950021668, random=0.22135950079105757
# round 83, (76, 84), lsmash = 0.8023355367343223, random=0.831683612461859
# round 84, (19, 45), lsmash = 0.1555908193702361, random=0.13167128483520116
# round 85, (59, 13), lsmash = 0.21673043737265268, random=0.08580921858725915
# round 86, (6, 29), lsmash = 0.3169835024315788, random=0.11437190519992166
# round 87, (46, 40), lsmash = 0.19305783276735178, random=0.05123768751822935
# round 88, (73, 5), lsmash = 0.7691874314951895, random=0.17466661132964642
# round 89, (76, 81), lsmash = 0.28498194049074427, random=0.07081834724144692
# round 90, (28, 1), lsmash = 0.6213795618063777, random=0.2324789929686669
# round 91, (63, 19), lsmash = 0.5684699620450757, random=0.33710019346076237
# round 92, (27, 52), lsmash = 0.07492125615876814, random=0.054695893521120136
# round 93, (54, 23), lsmash = 0.6278796872295437, random=0.2569189509807658
# round 94, (22, 75), lsmash = 0.07968612127735648, random=0.0623231322617461
# round 95, (18, 14), lsmash = 0.1693722837304904, random=0.10143759935061239
# round 96, (55, 24), lsmash = 0.14837403292589052, random=0.09897457574869768
# round 97, (59, 39), lsmash = 0.8797300789109871, random=0.7119728482222908
# round 98, (37, 3), lsmash = 0.14666228436316475, random=0.17990759999702957
# round 99, (37, 67), lsmash = 0.19287305424122322, random=0.3979295231545569
# experiment round 1
# round 0, (87, 22), lsmash = 0.14470657295547623, random=0.21105887010998964
# round 1, (55, 56), lsmash = 0.31986483388173215, random=0.2767097635760437
# round 2, (98, 88), lsmash = 0.23889645774389495, random=0.21677262491676577
# round 3, (42, 20), lsmash = 0.2951917252349878, random=0.26251873290013755
# round 4, (19, 53), lsmash = 0.3706684767563817, random=0.1238797374939184
# round 5, (56, 71), lsmash = 0.3320369958451366, random=0.20424918623000238
# round 6, (29, 31), lsmash = 0.16774312348726292, random=0.213197616647877
# round 7, (92, 87), lsmash = 0.13459841482511092, random=0.1733533045870161
# round 8, (5, 65), lsmash = 0.2142224882242588, random=0.2673255916557099
# round 9, (47, 10), lsmash = 0.42611836910708806, random=0.11257172038463832
# round 10, (19, 37), lsmash = 0.24023530513024577, random=0.24551593643174086
# round 11, (11, 48), lsmash = 0.13419035422619313, random=0.09323797976274144
# round 12, (23, 100), lsmash = 0.5866759681142886, random=0.403416251135471
# round 13, (30, 48), lsmash = 0.10121675939484595, random=0.07950248473872076
# round 14, (16, 2), lsmash = 0.17568122443272272, random=0.10800353752860725
# round 15, (16, 56), lsmash = 0.38585790093156996, random=0.5500469489773255
# round 16, (68, 84), lsmash = 0.23389677549622245, random=0.20457711530774622
# round 17, (39, 31), lsmash = 0.27718272235938335, random=0.08715509032295093
# round 18, (16, 81), lsmash = 0.3675084406238329, random=0.8023208225344906
# round 19, (36, 54), lsmash = 0.45770979563891095, random=0.30736592128880486
# round 20, (24, 45), lsmash = 0.13451540981679386, random=0.1275386129903653
# round 21, (70, 90), lsmash = 0.19342678985884015, random=0.0968905211617218
# round 22, (84, 91), lsmash = 0.8396178826709222, random=0.7934553149418667
# round 23, (90, 89), lsmash = 0.14588447286432274, random=0.13400416588957553
# round 24, (83, 25), lsmash = 0.13212681598256446, random=0.120857400082225
# round 25, (95, 96), lsmash = 0.4148702853907821, random=0.4850285346236112
# round 26, (31, 87), lsmash = 0.22641446010911298, random=0.1913247278555291
# round 27, (76, 10), lsmash = 0.46867639623822305, random=0.3507860780886067
# round 28, (53, 36), lsmash = 0.21968549195150563, random=0.09973011518362171
# round 29, (9, 54), lsmash = 0.9534520379675145, random=0.805909049681404
# round 30, (25, 30), lsmash = 0.11409250500623301, random=0.12572244108166972
# round 31, (82, 31), lsmash = 0.3830433657285065, random=0.5979232601119051
# round 32, (46, 23), lsmash = 0.19669395757812044, random=0.08248558480198466
# round 33, (71, 61), lsmash = 0.12011575196985369, random=0.10347544523641815
# round 34, (53, 79), lsmash = 0.19428544416148238, random=0.15686553149746083
# round 35, (60, 5), lsmash = 0.522418058997337, random=0.6721215851724635
# round 36, (13, 51), lsmash = 0.1985209246967486, random=0.13725697023331782
# round 37, (39, 35), lsmash = 0.12445264249723055, random=0.08010952602811075
# round 38, (73, 28), lsmash = 0.816152199587073, random=0.15915466485426236
# round 39, (72, 40), lsmash = 0.3787791413204335, random=0.18419740161803594
# round 40, (79, 49), lsmash = 0.15010983888743246, random=0.05179907762799541
# round 41, (52, 16), lsmash = 0.06971154974232514, random=0.06948504484795333
# round 42, (6, 43), lsmash = 0.582709009327727, random=0.11178997859463821
# round 43, (6, 43), lsmash = 0.582709009327727, random=0.11178997859463821
# round 44, (47, 19), lsmash = 0.4080326356779347, random=0.15676855234476025
# round 45, (7, 38), lsmash = 0.9221346143043708, random=0.44126055921654417
# round 46, (65, 25), lsmash = 0.17070393578854096, random=0.21771231807392083
# round 47, (18, 85), lsmash = 0.11756774366039545, random=0.05313598694202158
# round 48, (29, 72), lsmash = 0.8402767422814899, random=0.83085592531304
# round 49, (18, 12), lsmash = 0.17110387039201166, random=0.12659383322439602
# round 50, (65, 34), lsmash = 0.13235291931772591, random=0.21754594820967205
# round 51, (95, 96), lsmash = 0.4148702853907821, random=0.4850285346236112
# round 52, (84, 82), lsmash = 0.28484013643791894, random=0.1491056963688701
# round 53, (35, 89), lsmash = 0.08296794817022356, random=0.06286640589045545
# round 54, (88, 57), lsmash = 0.12120674330503754, random=0.06785172575602225
# round 55, (67, 7), lsmash = 0.17083327608273113, random=0.21637654648198118
# round 56, (66, 94), lsmash = 0.2861539245087545, random=0.25635319520856675
# round 57, (31, 90), lsmash = 0.4981406180742676, random=0.2017270877140406
# round 58, (62, 96), lsmash = 0.10862211672195834, random=0.13573373699574084
# round 59, (23, 52), lsmash = 0.07442059789157499, random=0.06995777743011548
# round 60, (51, 49), lsmash = 0.15441543124131715, random=0.06579439971157196
# round 61, (6, 94), lsmash = 0.36339039527308215, random=0.2761040247436049
# round 62, (55, 52), lsmash = 0.053897930506225614, random=0.06904381912797622
# round 63, (60, 24), lsmash = 0.7353239754754639, random=0.26450089476840116
# round 64, (84, 24), lsmash = 0.3331594179480599, random=0.09842394145660273
# round 65, (38, 73), lsmash = 0.6733015387358642, random=0.3955324705399667
# round 66, (83, 43), lsmash = 0.2125321831785674, random=0.2983660171261006
# round 67, (85, 27), lsmash = 0.12094831211923257, random=0.0730546467261852
# round 68, (16, 92), lsmash = 0.1310470534750291, random=0.12316374397517026
# round 69, (47, 53), lsmash = 0.8822919090609592, random=0.45275605085928644
# round 70, (75, 13), lsmash = 0.22193970282101802, random=0.3528149816780297
# round 71, (30, 35), lsmash = 0.3448078185927179, random=0.06993001326827322
# round 72, (21, 75), lsmash = 0.08051276415339102, random=0.05879434848739443
# round 73, (61, 25), lsmash = 0.1694746166252895, random=0.11052003753676831
# round 74, (78, 68), lsmash = 0.15526650313613086, random=0.06997921209982075
# round 75, (4, 54), lsmash = 0.22451827797689833, random=0.2510100548473827
# round 76, (66, 19), lsmash = 0.5886043006939345, random=0.2972674936452065
# round 77, (9, 37), lsmash = 0.2203725352141276, random=0.25629478904678876
# round 78, (84, 74), lsmash = 0.3627919659498001, random=0.08742451525219319
# round 79, (26, 6), lsmash = 0.08450026499294784, random=0.1302667839613324
# round 80, (51, 98), lsmash = 0.10786107082933571, random=0.16290887906939766
# round 81, (88, 50), lsmash = 0.20763609458862672, random=0.10321417928569543
# round 82, (58, 21), lsmash = 0.06647343150850202, random=0.06571865378246831
# round 83, (26, 4), lsmash = 0.06960616210237118, random=0.09097438071614272
# round 84, (67, 80), lsmash = 0.2265719280319275, random=0.26623180468984353
# round 85, (23, 16), lsmash = 0.5509039018365145, random=0.6569266930003079
# round 86, (6, 81), lsmash = 0.3783794521026122, random=0.14013882025413565
# round 87, (14, 28), lsmash = 0.13920334973789508, random=0.1496957375709409
# round 88, (61, 8), lsmash = 0.17963794478799497, random=0.13710000702129563
# round 89, (36, 5), lsmash = 0.5909796125882001, random=0.2728328242915379
# round 90, (40, 21), lsmash = 0.06643868153128495, random=0.05449774747613512
# round 91, (56, 82), lsmash = 0.1468122984101389, random=0.3064170703601359
# round 92, (7, 23), lsmash = 0.39884817506659437, random=0.15266048432010398
# round 93, (31, 72), lsmash = 0.18171970142278598, random=0.1901450559017559
# round 94, (91, 27), lsmash = 0.330774339608617, random=0.171216752793758
# round 95, (63, 47), lsmash = 0.5432919905202157, random=0.14242762661299202
# round 96, (38, 90), lsmash = 0.19697826222485712, random=0.12012362624639765
# round 97, (82, 94), lsmash = 0.15782257617995354, random=0.183893222715951
# round 98, (81, 23), lsmash = 0.44996036921010746, random=0.8376069487693946
# round 99, (74, 90), lsmash = 0.17137818445172373, random=0.18233325715686
# experiment round 2
# round 0, (91, 40), lsmash = 0.3812417708720435, random=0.11737730524095263
# round 1, (42, 23), lsmash = 0.2393488715516239, random=0.16451160707018841
# round 2, (1, 41), lsmash = 0.8785097412296449, random=0.6047933194111718
# round 3, (60, 27), lsmash = 0.5438126124801637, random=0.47086422498015873
# round 4, (69, 63), lsmash = 0.17547864152935486, random=0.06508700539654731
# round 5, (55, 42), lsmash = 0.35126676510325394, random=0.3049276224050448
# round 6, (91, 64), lsmash = 0.40393975426969597, random=0.3669783468118061
# round 7, (19, 82), lsmash = 0.2252196253965485, random=0.20833311953223305
# round 8, (13, 9), lsmash = 0.4683472523962244, random=0.20542094738859773
# round 9, (93, 51), lsmash = 0.1428019623052515, random=0.06781818665670035
# round 10, (28, 85), lsmash = 0.12298528353984423, random=0.07966833467183668
# round 11, (86, 61), lsmash = 0.2100049727446858, random=0.12397075150127104
# round 12, (88, 41), lsmash = 0.16733886710759144, random=0.09718990775985892
# round 13, (4, 26), lsmash = 0.06960616210237118, random=0.06757542180291046
# round 14, (59, 34), lsmash = 0.12868673221124147, random=0.06175778821476983
# round 15, (11, 25), lsmash = 0.15584700048462607, random=0.1520780912728272
# round 16, (17, 23), lsmash = 0.24710405105161132, random=0.19392133713660964
# round 17, (72, 87), lsmash = 0.5283457563412401, random=0.23955075153642513
# round 18, (57, 35), lsmash = 0.1147456098637537, random=0.13259945380035834
# round 19, (45, 52), lsmash = 0.05232143975482944, random=0.04079184347079029
# round 20, (29, 4), lsmash = 0.15208397686276992, random=0.16698118850051405
# round 21, (29, 44), lsmash = 0.361864028354186, random=0.32379662073222953
# round 22, (66, 5), lsmash = 0.4609093752532463, random=0.20023899420813931
# round 23, (62, 15), lsmash = 0.10305705766126091, random=0.10794903442413607
# round 24, (39, 75), lsmash = 0.1841999447972469, random=0.06278407141052601
# round 25, (62, 75), lsmash = 0.17060048218313947, random=0.10509966843986865
# round 26, (84, 32), lsmash = 0.8261038335512584, random=0.22334550469900658
# round 27, (39, 38), lsmash = 0.1327530413974585, random=0.05786999999119918
# round 28, (21, 36), lsmash = 0.05868230566333711, random=0.04930480956259498
# round 29, (63, 31), lsmash = 0.2575052086168986, random=0.1560540766702145
# round 30, (97, 71), lsmash = 0.12268584070784543, random=0.08168959457092052
# round 31, (95, 29), lsmash = 0.24809199078459224, random=0.31458852107034035
# round 32, (28, 65), lsmash = 0.24367624196494297, random=0.14301486661624502
# round 33, (73, 59), lsmash = 0.16107034522871513, random=0.05462564058873852
# round 34, (27, 87), lsmash = 0.7835450717203717, random=0.30270419403535875
# round 35, (2, 37), lsmash = 0.15474675662493187, random=0.12947933376358628
# round 36, (60, 24), lsmash = 0.7353239754754639, random=0.24318520030227386
# round 37, (12, 79), lsmash = 0.11802595129583586, random=0.08751052017053007
# round 38, (34, 76), lsmash = 0.1712204325742629, random=0.13366899677085545
# round 39, (78, 79), lsmash = 0.38115547390681226, random=0.14615534269424538
# round 40, (5, 9), lsmash = 0.9128306288836563, random=0.5566240185153019
# round 41, (31, 84), lsmash = 0.2721902041429236, random=0.09333903645731488
# round 42, (98, 95), lsmash = 0.19757856366540885, random=0.15149305171610697
# round 43, (33, 85), lsmash = 0.09437136957017463, random=0.05191382522213206
# round 44, (98, 32), lsmash = 0.2956087522895223, random=0.12806364208169277
# round 45, (97, 26), lsmash = 0.07403871964307551, random=0.05931660105410792
# round 46, (97, 81), lsmash = 0.33411570502498117, random=0.2166136331679645
# round 47, (54, 9), lsmash = 0.9534520379675134, random=0.727425647424706
# round 48, (87, 2), lsmash = 0.17957003644530614, random=0.09383802484328932
# round 49, (2, 57), lsmash = 0.1398224508077664, random=0.09292454438066756
# round 50, (26, 97), lsmash = 0.07403871964307554, random=0.059316601054107895
# round 51, (85, 1), lsmash = 0.12118783247388276, random=0.06395890403643081
# round 52, (52, 81), lsmash = 0.07413227802926094, random=0.05961830164474294
# round 53, (85, 19), lsmash = 0.12786147161757985, random=0.0643501077001123
# round 54, (22, 76), lsmash = 0.10311002902823452, random=0.06859910259468362
# round 55, (90, 92), lsmash = 0.16379618437076574, random=0.0861205722056664
# round 56, (20, 7), lsmash = 0.5907321830511052, random=0.5414610159459412
# round 57, (11, 32), lsmash = 0.4252900157824281, random=0.21057715577319577
# round 58, (75, 39), lsmash = 0.18419994479724772, random=0.06278407141052596
# round 59, (51, 36), lsmash = 0.12355081122302487, random=0.06672274131258767
# round 60, (74, 7), lsmash = 0.24490242935357642, random=0.1189958259793864
# round 61, (26, 68), lsmash = 0.09682752778795078, random=0.0858715838891369
# round 62, (26, 77), lsmash = 0.18164694452579083, random=0.1216504463380055
# round 63, (81, 92), lsmash = 0.13611528838755171, random=0.1263326929460902
# round 64, (39, 83), lsmash = 0.18342209091976044, random=0.06524315543720703
# round 65, (38, 58), lsmash = 0.9650576972704574, random=0.8506810836376604
# round 66, (86, 61), lsmash = 0.2100049727446858, random=0.12397075150127104
# round 67, (77, 51), lsmash = 0.12402124548354954, random=0.11725197838770546
# round 68, (45, 57), lsmash = 0.21316291963760106, random=0.1594186442980409
# round 69, (19, 66), lsmash = 0.5886043006939361, random=0.2788855317242015
# round 70, (18, 65), lsmash = 0.20690289697940167, random=0.24778650854612436
# round 71, (9, 51), lsmash = 0.13516025772539156, random=0.07962136788885298
# round 72, (72, 87), lsmash = 0.5283457563412401, random=0.23955075153642513
# round 73, (62, 91), lsmash = 0.17392070407115715, random=0.21413162728130183
# round 74, (26, 50), lsmash = 0.08840936943567816, random=0.07812501336318646
# round 75, (3, 8), lsmash = 0.13062129271703335, random=0.09312422239222433
# round 76, (45, 13), lsmash = 0.18009126358258729, random=0.12300366961215264
# round 77, (34, 93), lsmash = 0.2283641489073873, random=0.19601929260354256
# round 78, (34, 42), lsmash = 0.6930600248133302, random=0.3570169158163179
# round 79, (99, 68), lsmash = 0.3923113099501013, random=0.1970112910076987
# round 80, (42, 53), lsmash = 0.18864454877720316, random=0.10847557995482733
# round 81, (34, 62), lsmash = 0.08798766200204457, random=0.08972399386424164
# round 82, (68, 64), lsmash = 0.59063897741639, random=0.2867743117425939
# round 83, (68, 7), lsmash = 0.9619002098838739, random=0.6605171658889192
# round 84, (7, 42), lsmash = 0.46208467869135944, random=0.20392615698863836
# round 85, (57, 66), lsmash = 0.2718634405389739, random=0.2208060190675477
# round 86, (93, 100), lsmash = 0.6798777028440695, random=0.22989698943038317
# round 87, (93, 11), lsmash = 0.2354887370812875, random=0.21111094860660592
# round 88, (55, 25), lsmash = 0.30019342062007814, random=0.15410650217790503
# round 89, (63, 34), lsmash = 0.18855203172708068, random=0.16697806792914258
# round 90, (35, 86), lsmash = 0.13601507888804973, random=0.13658331938786047
# round 91, (91, 40), lsmash = 0.3812417708720435, random=0.11737730524095263
# round 92, (53, 11), lsmash = 0.2949487349992031, random=0.07332560244075503
# round 93, (44, 37), lsmash = 0.1935425185783648, random=0.17519575530334527
# round 94, (51, 91), lsmash = 0.15271763822878964, random=0.06545959212894405
# round 95, (65, 92), lsmash = 0.22529880983538356, random=0.22651574647460948
# round 96, (29, 59), lsmash = 0.12984283369942076, random=0.05869767724049468
# round 97, (4, 57), lsmash = 0.15601343683823102, random=0.18871033008107796
# round 98, (14, 85), lsmash = 0.07664363261409748, random=0.048715849896399765
# round 99, (91, 14), lsmash = 0.11875242060646386, random=0.0913899233759683
# experiment round 3
# round 0, (63, 29), lsmash = 0.22813523380450615, random=0.19858599402673094
# round 1, (36, 97), lsmash = 0.229097113904014, random=0.09951785103136797
# round 2, (8, 34), lsmash = 0.11796124243111906, random=0.08647457314625218
# round 3, (87, 95), lsmash = 0.3954690716288438, random=0.27721685772390664
# round 4, (33, 31), lsmash = 0.15033001266172674, random=0.14573008059132805
# round 5, (54, 9), lsmash = 0.9534520379675134, random=0.6282826681117695
# round 6, (16, 40), lsmash = 0.7529149604020106, random=0.6451454277882903
# round 7, (21, 31), lsmash = 0.06977237311282572, random=0.05517776170230168
# round 8, (46, 10), lsmash = 0.2099595999822669, random=0.1558487250195533
# round 9, (6, 34), lsmash = 0.2391664259409642, random=0.14431768403608652
# round 10, (48, 40), lsmash = 0.16539997366788786, random=0.34275087974397
# round 11, (78, 58), lsmash = 0.16621158162075508, random=0.07141991753880232
# round 12, (55, 17), lsmash = 0.31785437947072165, random=0.3697353312726799
# round 13, (24, 28), lsmash = 0.8921795833930297, random=0.8304548242219008
# round 14, (54, 47), lsmash = 0.3617475371773367, random=0.15907874810905087
# round 15, (61, 50), lsmash = 0.18661224663500786, random=0.29619088757533885
# round 16, (27, 57), lsmash = 0.4354659430442933, random=0.29099772240560867
# round 17, (43, 34), lsmash = 0.1920616559839255, random=0.16009277917540918
# round 18, (38, 9), lsmash = 0.7780485994836568, random=0.7800387735348508
# round 19, (63, 50), lsmash = 0.653309721946659, random=0.1891474289166644
# round 20, (66, 50), lsmash = 0.6858222170110745, random=0.12696608934404563
# round 21, (92, 65), lsmash = 0.22529880983538383, random=0.315944019669998
# round 22, (65, 13), lsmash = 0.21244880263676566, random=0.11936704314968935
# round 23, (31, 48), lsmash = 0.17269298187735246, random=0.8822332672388993
# round 24, (72, 27), lsmash = 0.49443455280344534, random=0.4872716129476227
# round 25, (39, 87), lsmash = 0.13520063698758253, random=0.04967307182670685
# round 26, (98, 93), lsmash = 0.18310010371400412, random=0.0781997391844324
# round 27, (90, 66), lsmash = 0.275487473284021, random=0.06255887202885294
# round 28, (73, 28), lsmash = 0.816152199587073, random=0.11184967746165318
# round 29, (97, 77), lsmash = 0.14944820438332468, random=0.2067564754153617
# round 30, (89, 33), lsmash = 0.0786616668187044, random=0.04312121712153454
# round 31, (92, 59), lsmash = 0.15642522727751348, random=0.04414875100284251
# round 32, (53, 61), lsmash = 0.13420717253773784, random=0.0900506592133489
# round 33, (89, 90), lsmash = 0.14588447286432282, random=0.1271137863102318
# round 34, (66, 8), lsmash = 0.2813964036702171, random=0.20929375687211418
# round 35, (18, 83), lsmash = 0.15023446223247738, random=0.16099580908576214
# round 36, (99, 46), lsmash = 0.12057331603476748, random=0.06898655038584005
# round 37, (8, 50), lsmash = 0.20599738796857164, random=0.08395614473825858
# round 38, (2, 29), lsmash = 0.13688793195233415, random=0.13994796520019945
# round 39, (79, 67), lsmash = 0.09775509792327457, random=0.08569571726536332
# round 40, (86, 55), lsmash = 0.23454042133019412, random=0.22550403010234019
# round 41, (49, 34), lsmash = 0.17508607389246308, random=0.11992354722317526
# round 42, (56, 47), lsmash = 0.20380015636444254, random=0.26126281884093105
# round 43, (51, 26), lsmash = 0.06514765563311757, random=0.052780169600082645
# round 44, (21, 16), lsmash = 0.060275537226006946, random=0.05119920223263705
# round 45, (28, 18), lsmash = 0.5918875172011185, random=0.1040136763760318
# round 46, (30, 18), lsmash = 0.12408400108286922, random=0.0987498271136038
# round 47, (37, 68), lsmash = 0.179383339448013, random=0.20580487415616858
# round 48, (18, 76), lsmash = 0.3327841044148036, random=0.21700796585157447
# round 49, (89, 8), lsmash = 0.10192709475491903, random=0.030754997458695605
# round 50, (22, 11), lsmash = 0.08229339274659955, random=0.06061529728254865
# round 51, (18, 88), lsmash = 0.15535295600034302, random=0.057474904787290636
# round 52, (21, 86), lsmash = 0.06286560253745638, random=0.06293223324060607
# round 53, (34, 96), lsmash = 0.32971387727861384, random=0.5149350442441609
# round 54, (37, 11), lsmash = 0.5407042461200124, random=0.0910165862429604
# round 55, (66, 75), lsmash = 0.3367537668864369, random=0.10786458072566742
# round 56, (72, 77), lsmash = 0.15535739410270155, random=0.2681780806132992
# round 57, (24, 8), lsmash = 0.20046962665459614, random=0.06563999369786341
# round 58, (68, 82), lsmash = 0.17897024564610392, random=0.31559651421066737
# round 59, (89, 10), lsmash = 0.08847473769235645, random=0.04124949081045448
# round 60, (62, 20), lsmash = 0.12301511264739519, random=0.14920759077261603
# round 61, (24, 63), lsmash = 0.6519929683128802, random=0.13212711056782545
# round 62, (26, 1), lsmash = 0.09650801715415915, random=0.10584935190379605
# round 63, (39, 29), lsmash = 0.11016918082480928, random=0.05300397685734136
# round 64, (25, 76), lsmash = 0.24081776337719935, random=0.28731009102778593
# round 65, (74, 46), lsmash = 0.2885538225473513, random=0.06679330670252298
# round 66, (33, 68), lsmash = 0.39267688563879155, random=0.5445281235813895
# round 67, (8, 10), lsmash = 0.20249862469717225, random=0.15031596298776725
# round 68, (54, 16), lsmash = 0.857352084261488, random=0.29817565465478973
# round 69, (21, 85), lsmash = 0.0822450095039207, random=0.03224380555034918
# round 70, (72, 30), lsmash = 0.11101259761788677, random=0.07096214861786183
# round 71, (92, 9), lsmash = 0.1509240707950762, random=0.12221146882661281
# round 72, (83, 36), lsmash = 0.12737353182424926, random=0.21579405573161706
# round 73, (27, 85), lsmash = 0.1209483121192328, random=0.06100847487960992
# round 74, (57, 6), lsmash = 0.3460629380759338, random=0.22411490683170515
# round 75, (4, 33), lsmash = 0.13368135209354565, random=0.24251666112253534
# round 76, (36, 68), lsmash = 0.7695598363563516, random=0.8180143399309369
# round 77, (23, 54), lsmash = 0.6278796872295453, random=0.2635125403650423
# round 78, (1, 23), lsmash = 0.5195348001163771, random=0.259165252031695
# round 79, (6, 17), lsmash = 0.2994022439735116, random=0.16840966148036604
# round 80, (62, 55), lsmash = 0.07339309460033398, random=0.07965238368616218
# round 81, (83, 26), lsmash = 0.061030668501365765, random=0.08898314970608048
# round 82, (38, 56), lsmash = 0.4778452698603681, random=0.20594555942852472
# round 83, (55, 25), lsmash = 0.30019342062007814, random=0.14900914552720101
# round 84, (17, 96), lsmash = 0.46359509808686267, random=0.6851418910997948
# round 85, (33, 50), lsmash = 0.248200605419213, random=0.20634558658734403
# round 86, (85, 77), lsmash = 0.10630349734625309, random=0.08491847146220888
# round 87, (79, 86), lsmash = 0.12165408039650438, random=0.05864831336138788
# round 88, (37, 73), lsmash = 0.23612900061938144, random=0.14207034571032873
# round 89, (79, 6), lsmash = 0.1343308679164908, random=0.04670473746044986
# round 90, (56, 92), lsmash = 0.10979024538910578, random=0.0771440529690553
# round 91, (46, 71), lsmash = 0.09550291290372041, random=0.08529968912191288
# round 92, (84, 81), lsmash = 0.23082187168357732, random=0.0845907818557029
# round 93, (93, 35), lsmash = 0.18020704227364132, random=0.10098684005989682
# round 94, (54, 65), lsmash = 0.21587748441542062, random=0.1829260666452932
# round 95, (66, 10), lsmash = 0.6529514954334286, random=0.40894735080670097
# round 96, (55, 46), lsmash = 0.0955304371001399, random=0.07595946513607227
# round 97, (43, 66), lsmash = 0.8401419954646032, random=0.09366677156413489
# round 98, (23, 25), lsmash = 0.29637548631533694, random=0.08230235079332245
# round 99, (39, 58), lsmash = 0.13712022620355818, random=0.06335036307934284
# experiment round 4
# round 0, (5, 83), lsmash = 0.1638290589595713, random=0.28012734009928253
# round 1, (58, 29), lsmash = 0.4814500651616518, random=0.6446531148731005
# round 2, (6, 67), lsmash = 0.214376352336875, random=0.16629019839157422
# round 3, (98, 84), lsmash = 0.2999916482538637, random=0.07848517086555973
# round 4, (10, 39), lsmash = 0.13774004550204405, random=0.043881401028378654
# round 5, (46, 73), lsmash = 0.21033479654135878, random=0.2860042222560494
# round 6, (55, 8), lsmash = 0.09490137954202293, random=0.1327302968726602
# round 7, (51, 60), lsmash = 0.13510446339247337, random=0.08486508986630627
# round 8, (94, 25), lsmash = 0.7291558720800619, random=0.1839718019567259
# round 9, (48, 54), lsmash = 0.1500572559496095, random=0.28443848494924523
# round 10, (55, 32), lsmash = 0.12407419185650469, random=0.22918171205340573
# round 11, (71, 19), lsmash = 0.18074983505688172, random=0.27386736422443664
# round 12, (21, 48), lsmash = 0.05817432408670871, random=0.09043086147198569
# round 13, (83, 64), lsmash = 0.1698451377621593, random=0.1382491948280059
# round 14, (78, 15), lsmash = 0.15360623048926036, random=0.05590494087375781
# round 15, (14, 18), lsmash = 0.16937228373049018, random=0.19016942855721536
# round 16, (82, 87), lsmash = 0.18186225426170904, random=0.19371715123503974
# round 17, (97, 71), lsmash = 0.12268584070784543, random=0.08366426422051301
# round 18, (39, 25), lsmash = 0.1297562743500097, random=0.03907596527523101
# round 19, (61, 45), lsmash = 0.10605677569786943, random=0.13331743240142457
# round 20, (57, 45), lsmash = 0.21316291963760153, random=0.17026254055348009
# round 21, (46, 58), lsmash = 0.17777913289717592, random=0.15841830319161013
# round 22, (92, 41), lsmash = 0.1448253849484234, random=0.16567350401282335
# round 23, (90, 64), lsmash = 0.23299417813026221, random=0.06315268605785962
# round 24, (28, 94), lsmash = 0.3147561189027101, random=0.1881056820528475
# round 25, (3, 36), lsmash = 0.8064643318436003, random=0.2580056987445717
# round 26, (51, 28), lsmash = 0.1398947165523461, random=0.12011100741403012
# round 27, (34, 7), lsmash = 0.3391047262804606, random=0.4251853424180425
# round 28, (16, 64), lsmash = 0.6326437071268457, random=0.12063868070862828
# round 29, (11, 20), lsmash = 0.2124668326893202, random=0.25117707870236816
# round 30, (90, 66), lsmash = 0.275487473284021, random=0.0648680993472437
# round 31, (9, 88), lsmash = 0.17412006378509398, random=0.07923866239463102
# round 32, (99, 16), lsmash = 0.312910817196751, random=0.31391763803202355
# round 33, (4, 43), lsmash = 0.2996350437713796, random=0.17147428530780776
# round 34, (9, 27), lsmash = 0.9403548784742941, random=0.6342460186864559
# round 35, (46, 82), lsmash = 0.33977889857756993, random=0.13635842887198213
# round 36, (100, 83), lsmash = 0.1682631742898909, random=0.2684954798076276
# round 37, (94, 88), lsmash = 0.13242091210562754, random=0.07999747544418419
# round 38, (37, 27), lsmash = 0.21035059939002274, random=0.31630828334155237
# round 39, (95, 23), lsmash = 0.4056279482951992, random=0.23057614147802372
# round 40, (87, 13), lsmash = 0.5366501693573665, random=0.12114432441581208
# round 41, (80, 26), lsmash = 0.09233982186145832, random=0.09908097569220087
# round 42, (66, 89), lsmash = 0.1085306387042858, random=0.03793349945368482
# round 43, (36, 58), lsmash = 0.68169456131526, random=0.34478612544380816
# round 44, (78, 12), lsmash = 0.14156008189337485, random=0.06882705392412158
# round 45, (92, 7), lsmash = 0.12981056441644187, random=0.24930682471079368
# round 46, (55, 88), lsmash = 0.08742996802600789, random=0.061464978107851564
# round 47, (49, 17), lsmash = 0.19819313129082916, random=0.2187618840058077
# round 48, (64, 89), lsmash = 0.09498381986825678, random=0.03768377834299383
# round 49, (89, 21), lsmash = 0.0787842633912483, random=0.03602732025110913
# round 50, (28, 73), lsmash = 0.8161521995870732, random=0.13706168505704228
# round 51, (36, 100), lsmash = 0.5605062514085204, random=0.3042175576101103
# round 52, (47, 13), lsmash = 0.380175080954528, random=0.5241983665643916
# round 53, (18, 81), lsmash = 0.3311290625620333, random=0.13275175916005932
# round 54, (72, 9), lsmash = 0.4607865996507926, random=0.48489993469804427
# round 55, (70, 91), lsmash = 0.1743743522919852, random=0.18288715090377802
# round 56, (20, 42), lsmash = 0.29519172523498854, random=0.17374992867055636
# round 57, (52, 93), lsmash = 0.0814654840927477, random=0.17323863035815878
# round 58, (74, 22), lsmash = 0.09768474478255357, random=0.08990271092086823
# round 59, (72, 18), lsmash = 0.47873324215021457, random=0.33470875228666397
# round 60, (56, 23), lsmash = 0.2557979246819636, random=0.3786067359555614
# round 61, (39, 41), lsmash = 0.1218486146375202, random=0.05446983589383519
# round 62, (33, 78), lsmash = 0.11651772845129446, random=0.05116465656373867
# round 63, (34, 19), lsmash = 0.2623402663186678, random=0.5783134998918315
# round 64, (42, 56), lsmash = 0.9324622289700436, random=0.3713913815902476
# round 65, (57, 65), lsmash = 0.15179855031606332, random=0.4498353035277927
# round 66, (38, 61), lsmash = 0.2093586041812919, random=0.2787900427785264
# round 67, (79, 70), lsmash = 0.09900968404683463, random=0.06478217817447796
# round 68, (48, 35), lsmash = 0.12189178731864107, random=0.47648858753902223
# round 69, (45, 98), lsmash = 0.07842054329196602, random=0.11646439775310266
# round 70, (30, 76), lsmash = 0.20279743009607973, random=0.33747738298655056
# round 71, (66, 31), lsmash = 0.3520106413024153, random=0.09152517405215703
# round 72, (34, 21), lsmash = 0.05557001033201776, random=0.09107669747531184
# round 73, (37, 72), lsmash = 0.16078864549377608, random=0.19642514933133315
# round 74, (26, 15), lsmash = 0.09142560392066117, random=0.09450966830409724
# round 75, (33, 90), lsmash = 0.19359412216843327, random=0.0720142617392408
# round 76, (95, 16), lsmash = 0.4023149826930522, random=0.23577718448727938
# round 77, (64, 15), lsmash = 0.5572968342629772, random=0.2550323511850304
# round 78, (42, 72), lsmash = 0.5327857865850304, random=0.2976909072014346
# round 79, (13, 2), lsmash = 0.17157958874785798, random=0.13931142475227787
# round 80, (93, 36), lsmash = 0.37859756677834117, random=0.39903223806824917
# round 81, (18, 76), lsmash = 0.3327841044148036, random=0.3156047405942177
# round 82, (58, 98), lsmash = 0.15266239384474609, random=0.1615748085317664
# round 83, (5, 44), lsmash = 0.9484151474551116, random=0.3714643627900715
# round 84, (36, 89), lsmash = 0.08152244136030319, random=0.03986512079743797
# round 85, (15, 50), lsmash = 0.5311073009248752, random=0.2641213427122157
# round 86, (17, 44), lsmash = 0.3404169336291953, random=0.6464370602726864
# round 87, (100, 2), lsmash = 0.20906941838515442, random=0.2007321549632385
# round 88, (7, 36), lsmash = 0.7158074451385077, random=0.8447909510252921
# round 89, (95, 34), lsmash = 0.19967244889462732, random=0.34588016560090984
# round 90, (60, 86), lsmash = 0.36155341632004356, random=0.32314826677324726
# round 91, (58, 36), lsmash = 0.6816945613152595, random=0.3447861254438078
# round 92, (87, 75), lsmash = 0.1690764700247004, random=0.14675626015772025
# round 93, (47, 53), lsmash = 0.8822919090609592, random=0.3919240394085004
# round 94, (40, 74), lsmash = 0.35889131365342924, random=0.2652421689010632
# round 95, (65, 30), lsmash = 0.19229843458559703, random=0.251563953510297
# round 96, (22, 91), lsmash = 0.10222897626961665, random=0.10605145795811774
# round 97, (36, 76), lsmash = 0.23734143419616405, random=0.24600036498649153
# round 98, (96, 43), lsmash = 0.38891054054495533, random=0.2193349413627534
# round 99, (100, 88), lsmash = 0.17370614188668987, random=0.10447314731994546
# experiment round 5
# round 0, (43, 2), lsmash = 0.18929354083454172, random=0.2644984591040612
# round 1, (3, 76), lsmash = 0.2079281247095564, random=0.10074885143694481
# round 2, (33, 87), lsmash = 0.38752163389910677, random=0.3945584816997891
# round 3, (24, 59), lsmash = 0.17569152527872467, random=0.08773748494456485
# round 4, (73, 99), lsmash = 0.28295142840114, random=0.13065590261379156
# round 5, (53, 65), lsmash = 0.28406596509564275, random=0.06940903065374426
# round 6, (19, 88), lsmash = 0.18805034878175306, random=0.08456644595306942
# round 7, (41, 51), lsmash = 0.12476367851753056, random=0.08298234018748973
# round 8, (60, 40), lsmash = 0.7093861938218867, random=0.18984013177571818
# round 9, (6, 32), lsmash = 0.3629084007323879, random=0.19897077941113211
# round 10, (97, 18), lsmash = 0.3133498331885673, random=0.0715723639309046
# round 11, (16, 62), lsmash = 0.10537485928689631, random=0.08758643414688932
# round 12, (14, 4), lsmash = 0.09923707210948439, random=0.1289386586396791
# round 13, (71, 29), lsmash = 0.3087777104918322, random=0.25505243415446366
# round 14, (48, 97), lsmash = 0.2109024189682725, random=0.3752323633581707
# round 15, (92, 53), lsmash = 0.20600701126230414, random=0.06309460790911971
# round 16, (32, 97), lsmash = 0.4620622027650235, random=0.1032026852328619
# round 17, (77, 58), lsmash = 0.17780916630003296, random=0.2488172496551832
# round 18, (21, 60), lsmash = 0.07169685944333996, random=0.06406335238386665
# round 19, (40, 3), lsmash = 0.3398877775301923, random=0.25817501454839537
# round 20, (53, 66), lsmash = 0.6152434978509314, random=0.06123955728808245
# round 21, (77, 71), lsmash = 0.1802900447757124, random=0.1852471450896698
# round 22, (98, 83), lsmash = 0.22947310477706534, random=0.1908159920225929
# round 23, (67, 75), lsmash = 0.18197590235697284, random=0.3936052604127771
# round 24, (79, 41), lsmash = 0.12218057974943619, random=0.0748024299894338
# round 25, (71, 31), lsmash = 0.11176938662741953, random=0.10312020807341536
# round 26, (45, 19), lsmash = 0.1555908193702357, random=0.18544757395941022
# round 27, (46, 99), lsmash = 0.12057331603476742, random=0.06746521466579641
# round 28, (99, 83), lsmash = 0.11218060233756603, random=0.12903677394174548
# round 29, (80, 6), lsmash = 0.7902328658533052, random=0.2832626236775656
# round 30, (43, 24), lsmash = 0.8498204359064225, random=0.814323263795691
# round 31, (27, 47), lsmash = 0.35402241986399324, random=0.15605637675044629
# round 32, (7, 79), lsmash = 0.12139151136843264, random=0.05449007671336214
# round 33, (50, 13), lsmash = 0.5741158215458265, random=0.38928746305385764
# round 34, (81, 6), lsmash = 0.3783794521026128, random=0.084886252094717
# round 35, (32, 53), lsmash = 0.4748389261372569, random=0.08451005187026843
# round 36, (58, 75), lsmash = 0.1848304520478101, random=0.27341231049593157
# round 37, (86, 85), lsmash = 0.11647668324516926, random=0.044497132541963
# round 38, (14, 85), lsmash = 0.07664363261409748, random=0.043478260940002234
# round 39, (12, 24), lsmash = 0.2185010186433869, random=0.16976302215694963
# round 40, (19, 39), lsmash = 0.14441242313021033, random=0.05392457478037407
# round 41, (72, 33), lsmash = 0.47808459950852245, random=0.43228590328078775
# round 42, (50, 74), lsmash = 0.3948937377275525, random=0.26758479135623564
# round 43, (62, 85), lsmash = 0.1128264785986936, random=0.043675847345212904
# round 44, (55, 59), lsmash = 0.10195833255839785, random=0.0486972272313532
# round 45, (99, 28), lsmash = 0.24107591591872346, random=0.2559515683693982
# round 46, (17, 24), lsmash = 0.26189775253197145, random=0.15200768147766736
# round 47, (79, 61), lsmash = 0.07850703444439554, random=0.06670837569654528
# round 48, (85, 35), lsmash = 0.11268095448919146, random=0.0695650325317791
# round 49, (37, 24), lsmash = 0.2726621718611809, random=0.3131711996910201
# round 50, (5, 19), lsmash = 0.8128501969978199, random=0.4181648183671135
# round 51, (25, 42), lsmash = 0.6238294765566311, random=0.12128948826119014
# round 52, (60, 37), lsmash = 0.2889230063890538, random=0.26035016316150916
# round 53, (6, 58), lsmash = 0.6116558715903169, random=0.1505603422039528
# round 54, (14, 41), lsmash = 0.15841129454020758, random=0.19819160978821648
# round 55, (5, 20), lsmash = 0.7375943373625505, random=0.20295056946604917
# round 56, (18, 52), lsmash = 0.07276951130709848, random=0.07342894973505826
# round 57, (12, 20), lsmash = 0.19935601360389302, random=0.12730010816715379
# round 58, (19, 85), lsmash = 0.12786147161758027, random=0.055952066850820284
# round 59, (86, 73), lsmash = 0.5587117059831135, random=0.4569219786778315
# round 60, (45, 22), lsmash = 0.5183312793321403, random=0.39687193564352574
# round 61, (60, 1), lsmash = 0.5128161903669873, random=0.6097112855975498
# round 62, (24, 74), lsmash = 0.3933802739571881, random=0.3935272264581298
# round 63, (7, 20), lsmash = 0.590732183051102, random=0.5783769463211839
# round 64, (69, 22), lsmash = 0.08265722877260248, random=0.05506964511260737
# round 65, (7, 69), lsmash = 0.15522781633776922, random=0.04901148310383491
# round 66, (25, 84), lsmash = 0.20157144212829792, random=0.21417070937695404
# round 67, (47, 14), lsmash = 0.11597391612724421, random=0.09298266048772513
# round 68, (6, 32), lsmash = 0.3629084007323879, random=0.19897077941113211
# round 69, (18, 32), lsmash = 0.3034773559486771, random=0.3156968916069497
# round 70, (31, 2), lsmash = 0.10991641902284639, random=0.22048852583062994
# round 71, (94, 18), lsmash = 0.48760637072752067, random=0.21605500061382657
# round 72, (5, 31), lsmash = 0.22822536014189215, random=0.28457787602198487
# round 73, (89, 3), lsmash = 0.08478927735856874, random=0.05220802260381103
# round 74, (98, 15), lsmash = 0.13388611864487096, random=0.10767187863306046
# round 75, (29, 95), lsmash = 0.24809199078459146, random=0.41408784398707
# round 76, (57, 96), lsmash = 0.5744794782365483, random=0.28384479280563585
# round 77, (64, 19), lsmash = 0.8161518420098635, random=0.1989528732879325
# round 78, (72, 10), lsmash = 0.36617737499519537, random=0.22851469958824905
# round 79, (73, 29), lsmash = 0.34683898892597154, random=0.22439267146043546
# round 80, (72, 71), lsmash = 0.2800702174776984, random=0.2430631281291716
# round 81, (85, 46), lsmash = 0.14405007711567333, random=0.03166786959802225
# round 82, (84, 75), lsmash = 0.4112446964330994, random=0.08050009471517292
# round 83, (64, 67), lsmash = 0.22176977479081572, random=0.14285317490351165
# round 84, (100, 89), lsmash = 0.09010960380968029, random=0.05069161762334141
# round 85, (31, 59), lsmash = 0.303609374299892, random=0.09540442077732994
# round 86, (91, 21), lsmash = 0.08502086591132217, random=0.08925085957469084
# round 87, (68, 43), lsmash = 0.3591399948743557, random=0.1397888775242632
# round 88, (56, 27), lsmash = 0.3843912068548683, random=0.3314541967565107
# round 89, (19, 39), lsmash = 0.14441242313021033, random=0.05392457478037407
# round 90, (75, 92), lsmash = 0.26330853507926477, random=0.11822063512828558
# round 91, (90, 10), lsmash = 0.20792446552404112, random=0.06091252642797552
# round 92, (42, 85), lsmash = 0.10453076567395224, random=0.056273061231140974
# round 93, (4, 72), lsmash = 0.17439913765601944, random=0.2080815479306514
# round 94, (41, 87), lsmash = 0.6609026473052011, random=0.17991580439491664
# round 95, (100, 93), lsmash = 0.6798777028440702, random=0.15773768598272483
# round 96, (74, 84), lsmash = 0.3627919659497999, random=0.06731420738427094
# round 97, (1, 37), lsmash = 0.2065377211491935, random=0.27631098253974357
# round 98, (68, 49), lsmash = 0.305041133478671, random=0.17096306762140367
# round 99, (6, 89), lsmash = 0.08939632369808351, random=0.032665099011252696
# experiment round 6
# round 0, (59, 68), lsmash = 0.14831427293904242, random=0.08093497387178405
# round 1, (64, 45), lsmash = 0.15174630026107513, random=0.175385560652683
# round 2, (28, 63), lsmash = 0.6043533837665438, random=0.2482591129834494
# round 3, (14, 53), lsmash = 0.11707070394272308, random=0.10562205992142791
# round 4, (81, 32), lsmash = 0.2720951701617911, random=0.24348091029528302
# round 5, (62, 28), lsmash = 0.11944973099814268, random=0.10405957940224808
# round 6, (76, 35), lsmash = 0.2616278055559488, random=0.14741389597772894
# round 7, (67, 84), lsmash = 0.26363270426108315, random=0.16169105989824237
# round 8, (52, 19), lsmash = 0.0809677220448407, random=0.07015597205383334
# round 9, (56, 68), lsmash = 0.4931805186546627, random=0.4017398227065184
# round 10, (91, 58), lsmash = 0.31138977233911, random=0.20491142529469664
# round 11, (94, 38), lsmash = 0.573432829858341, random=0.33627675982499483
# round 12, (45, 56), lsmash = 0.2544591576190896, random=0.2288081607899917
# round 13, (6, 68), lsmash = 0.5629364539974698, random=0.46672212695878684
# round 14, (35, 78), lsmash = 0.15439313903797644, random=0.14699773744176237
# round 15, (60, 29), lsmash = 0.24901439235628062, random=0.28396276041179935
# round 16, (71, 72), lsmash = 0.2800702174776991, random=0.2837419183988666
# round 17, (14, 99), lsmash = 0.3338945557639121, random=0.39812310144160423
# round 18, (50, 73), lsmash = 0.8355256211039531, random=0.26789672011094723
# round 19, (32, 35), lsmash = 0.2967289298613197, random=0.25869373845741367
# round 20, (67, 9), lsmash = 0.2114432677592007, random=0.3737124037510791
# round 21, (95, 75), lsmash = 0.23930436880316078, random=0.21224423130853703
# round 22, (73, 77), lsmash = 0.17093128822959644, random=0.23680817410932037
# round 23, (84, 11), lsmash = 0.5166701697129485, random=0.44780206222342367
# round 24, (33, 5), lsmash = 0.32991045155441023, random=0.3475252066481017
# round 25, (77, 91), lsmash = 0.13600965414688146, random=0.16999479284600666
# round 26, (22, 69), lsmash = 0.08265722877260252, random=0.06275459289752189
# round 27, (18, 64), lsmash = 0.7490701863928418, random=0.43697047073901013
# round 28, (29, 21), lsmash = 0.05626472464495139, random=0.05388425672986041
# round 29, (60, 45), lsmash = 0.12806308357168292, random=0.15819065077769554
# ...
# round 90, (37, 50), lsmash = 0.26962702886471235, random=0.6045476780632635
# round 91, (57, 86), lsmash = 0.7142295277066171, random=0.7607952524562966
# round 92, (76, 17), lsmash = 0.19276674763794222, random=0.10496984642996574
# round 93, (83, 76), lsmash = 0.26390497837185406, random=0.09645192958891483
# round 94, (86, 18), lsmash = 0.7275022611258312, random=0.37689216635634054
# round 95, (48, 26), lsmash = 0.06139579879673402, random=0.0594870406465697
# round 96, (68, 4), lsmash = 0.19806440287165772, random=0.35035266651765984
# round 97, (72, 47), lsmash = 0.23190269894553767, random=0.10654816393292457
# round 98, (93, 81), lsmash = 0.3900537014471036, random=0.09311443589913594
# round 99, (27, 19), lsmash = 0.8633763029262227, random=0.4247981590602857
# experiment round 98
# round 0, (37, 32), lsmash = 0.4497184673655277, random=0.23129490667865968
# round 1, (5, 34), lsmash = 0.30232317582703955, random=0.42930430668323516
# round 2, (21, 14), lsmash = 0.045962061169422606, random=0.04756909954015125
# round 3, (8, 33), lsmash = 0.11586104111065394, random=0.1031989781796549
# round 4, (89, 71), lsmash = 0.06734732736000641, random=0.04286463253720548
# round 5, (4, 68), lsmash = 0.1980644028716579, random=0.25075648222781505
# round 6, (18, 2), lsmash = 0.19021544182325256, random=0.06256904198047343
# round 7, (3, 2), lsmash = 0.13912430269533732, random=0.0854987387912861
# round 8, (27, 87), lsmash = 0.7835450717203717, random=0.2298616286207118
# round 9, (92, 100), lsmash = 0.1504463844403907, random=0.12580762387716218
# round 10, (76, 4), lsmash = 0.36673411589710603, random=0.14740592228719354
# round 11, (90, 59), lsmash = 0.31075140770619325, random=0.2503200134849199
# round 12, (48, 36), lsmash = 0.12495827441124958, random=0.14752076326340618
# round 13, (4, 16), lsmash = 0.1999345469614235, random=0.213413867275677
# round 14, (40, 83), lsmash = 0.18109767079574388, random=0.2179225415368907
# round 15, (58, 55), lsmash = 0.21151432864914066, random=0.2677000086511845
# round 16, (50, 89), lsmash = 0.0971313516140744, random=0.06766597546045044
# round 17, (78, 82), lsmash = 0.5889800418416974, random=0.09282470586423958
# round 18, (25, 94), lsmash = 0.729155872080061, random=0.33857462150030093
# round 19, (72, 59), lsmash = 0.13501293505419248, random=0.06434416489573457
# round 20, (52, 19), lsmash = 0.0809677220448407, random=0.06720679937608572
# round 21, (56, 39), lsmash = 0.11923582279739334, random=0.07763946025208855
# round 22, (93, 68), lsmash = 0.5275326462366886, random=0.2934690870882941
# round 23, (36, 88), lsmash = 0.13046256758012562, random=0.06399187155710108
# round 24, (74, 86), lsmash = 0.2367596081203617, random=0.09426608410773353
# round 25, (92, 23), lsmash = 0.15260364794815487, random=0.11195860031668516
# round 26, (88, 71), lsmash = 0.08679725005483149, random=0.05454822060151031
# round 27, (24, 50), lsmash = 0.9295952501438705, random=0.40825471592086027
# round 28, (5, 14), lsmash = 0.1783046309546662, random=0.20337657111428906
# round 29, (65, 35), lsmash = 0.22586407780059256, random=0.14247604239532227
# round 30, (61, 21), lsmash = 0.06831035286449302, random=0.05661677654473261
# round 31, (88, 87), lsmash = 0.14910126005838426, random=0.06099169294501851
# round 32, (95, 65), lsmash = 0.2863411844191999, random=0.2703348673098786
# round 33, (69, 86), lsmash = 0.154858808148544, random=0.06085534570506448
# round 34, (29, 64), lsmash = 0.34057031192114956, random=0.14010430831004955
# round 35, (50, 93), lsmash = 0.8175408202007483, random=0.1464782268542353
# round 36, (61, 44), lsmash = 0.18667028493164967, random=0.3736519739662431
# round 37, (76, 66), lsmash = 0.7773926284954044, random=0.6334373052525298
# round 38, (34, 5), lsmash = 0.3023231758270393, random=0.4293043066832351
# round 39, (25, 68), lsmash = 0.5581035231355241, random=0.25668425703765474
# round 40, (71, 96), lsmash = 0.209776710217745, random=0.17358255911773812
# round 41, (55, 25), lsmash = 0.30019342062007814, random=0.3638237172031052
# round 42, (47, 65), lsmash = 0.29862548430062824, random=0.11253678137452755
# round 43, (13, 16), lsmash = 0.5845790032136438, random=0.7904974155940442
# round 44, (91, 30), lsmash = 0.20784720622064937, random=0.18536734437385088
# round 45, (3, 18), lsmash = 0.4570563779802938, random=0.1897361295293335
# round 46, (33, 27), lsmash = 0.30231599482492805, random=0.3222224323958863
# round 47, (24, 18), lsmash = 0.5099782434625266, random=0.10891787945762321
# round 48, (52, 1), lsmash = 0.0765046292164569, random=0.06179046789607793
# round 49, (95, 90), lsmash = 0.15818570622826464, random=0.11877249553598287
# round 50, (58, 42), lsmash = 0.4423049464849565, random=0.3591291489133827
# round 51, (16, 12), lsmash = 0.1659694505998521, random=0.18476263072999394
# round 52, (42, 78), lsmash = 0.13086044607069686, random=0.06599437762164942
# round 53, (98, 42), lsmash = 0.11134108610600976, random=0.09895803040017973
# round 54, (77, 23), lsmash = 0.15888933823302726, random=0.21503173960656286
# round 55, (60, 10), lsmash = 0.8043709392366206, random=0.23458171839357927
# round 56, (19, 40), lsmash = 0.8951373770439112, random=0.15287135291509366
# round 57, (87, 51), lsmash = 0.1397178002727612, random=0.07590438102043962
# round 58, (42, 14), lsmash = 0.3025970430323191, random=0.38036098181005934
# round 59, (3, 7), lsmash = 0.5933962134455962, random=0.22581853263023793
# round 60, (74, 11), lsmash = 0.32082927685126045, random=0.0664769943184014
# round 61, (8, 68), lsmash = 0.16181427673524731, random=0.11968777549433329
# round 62, (70, 74), lsmash = 0.16384424006646195, random=0.09185520519825373
# round 63, (46, 25), lsmash = 0.15248711458581812, random=0.10898450714575286
# round 64, (84, 34), lsmash = 0.14837248102592, random=0.11387012774667007
# round 65, (14, 79), lsmash = 0.0790317152434463, random=0.06605842699606823
# round 66, (76, 52), lsmash = 0.09737028635332431, random=0.08766900984297545
# round 67, (98, 52), lsmash = 0.10439134242974943, random=0.06558114249618084
# round 68, (6, 49), lsmash = 0.43130750902196013, random=0.27071697561785757
# round 69, (81, 46), lsmash = 0.16613533799075653, random=0.0707194346573302
# round 70, (58, 51), lsmash = 0.14019238660884745, random=0.1109334289539093
# round 71, (40, 56), lsmash = 0.3114454110335419, random=0.34197420204846035
# round 72, (92, 70), lsmash = 0.10214828182427738, random=0.11941835341188703
# round 73, (16, 73), lsmash = 0.7186092676444125, random=0.14173143460941967
# round 74, (70, 80), lsmash = 0.2930929625879911, random=0.4621748910478872
# round 75, (24, 22), lsmash = 0.11327869109547473, random=0.07994404683874154
# round 76, (58, 93), lsmash = 0.5876405980338335, random=0.20798608186222495
# round 77, (75, 35), lsmash = 0.34418107631440553, random=0.5457130870808452
# round 78, (48, 44), lsmash = 0.14155393781071732, random=0.1866716077898412
# round 79, (49, 74), lsmash = 0.37018556482503895, random=0.06893793829867605
# round 80, (9, 25), lsmash = 0.4268538263106682, random=0.18473443257219901
# round 81, (3, 15), lsmash = 0.552425675955953, random=0.4152545976492574
# round 82, (11, 70), lsmash = 0.12279990805824996, random=0.11882842704264157
# round 83, (47, 77), lsmash = 0.14671096036009496, random=0.1616586082370686
# round 84, (61, 7), lsmash = 0.1913623153053175, random=0.21296502486879404
# round 85, (5, 59), lsmash = 0.15537592924417484, random=0.0867530124090484
# round 86, (44, 20), lsmash = 0.7951551114432122, random=0.37438067265143715
# round 87, (37, 86), lsmash = 0.17353128370718973, random=0.15953700003369845
# round 88, (28, 13), lsmash = 0.5111091603105663, random=0.8528267150291978
# round 89, (72, 6), lsmash = 0.3714327588209766, random=0.2036806487654557
# round 90, (94, 62), lsmash = 0.10038582845573317, random=0.13791796378325813
# round 91, (26, 85), lsmash = 0.058354670245607615, random=0.035217047665839156
# round 92, (13, 19), lsmash = 0.5329300660194918, random=0.20372844536173149
# round 93, (24, 8), lsmash = 0.20046962665459614, random=0.07552898833676917
# round 94, (28, 7), lsmash = 0.4587681551086551, random=0.12293446661681434
# round 95, (22, 72), lsmash = 0.16848171101179021, random=0.12893815621227217
# round 96, (41, 79), lsmash = 0.12218057974943662, random=0.09847589349902985
# round 97, (94, 40), lsmash = 0.35079976268573004, random=0.10837050630600373
# round 98, (64, 82), lsmash = 0.21815926281721934, random=0.1732907155591861
# round 99, (14, 2), lsmash = 0.08759215724217188, random=0.06468015622101803
# experiment round 99
# round 0, (100, 85), lsmash = 0.12291898804937082, random=0.050547849659764235
# round 1, (26, 28), lsmash = 0.08171562635443641, random=0.0584424915258362
# round 2, (1, 44), lsmash = 0.9475591676592975, random=0.4766979526659665
# round 3, (27, 52), lsmash = 0.07492125615876814, random=0.07340381236465651
# round 4, (56, 88), lsmash = 0.12289147988254205, random=0.09432388246055101
# round 5, (11, 18), lsmash = 0.18200991986836412, random=0.13394861070802058
# round 6, (41, 16), lsmash = 0.6682216497373195, random=0.3594735861068682
# round 7, (43, 2), lsmash = 0.18929354083454172, random=0.2035686429135985
# round 8, (14, 96), lsmash = 0.18590273065959717, random=0.2370480949943721
# round 9, (12, 42), lsmash = 0.12524628381148536, random=0.18559334732942495
# round 10, (3, 53), lsmash = 0.20575465835192477, random=0.09605856474130955
# round 11, (83, 54), lsmash = 0.1618825412494277, random=0.35130779015257213
# round 12, (6, 34), lsmash = 0.2391664259409642, random=0.17791289707410457
# round 13, (23, 72), lsmash = 0.30657779752933473, random=0.11816325120340042
# round 14, (90, 13), lsmash = 0.3451631711988631, random=0.14912452178747085
# round 15, (10, 53), lsmash = 0.3794679198996118, random=0.061144243039896816
# round 16, (72, 63), lsmash = 0.27482698393378613, random=0.3089626528208521
# round 17, (44, 56), lsmash = 0.35339117830032557, random=0.18691080540571803
# round 18, (5, 61), lsmash = 0.2118175383172827, random=0.290630528561
# round 19, (45, 2), lsmash = 0.08630169331071758, random=0.08084412885028008
# round 20, (2, 80), lsmash = 0.22149456210527071, random=0.09915096001459009
# round 21, (15, 37), lsmash = 0.17796419597940263, random=0.15441826023594
# round 22, (76, 80), lsmash = 0.40427132104695584, random=0.18200559808960995
# round 23, (76, 64), lsmash = 0.4221050596230944, random=0.3777141024476136
# round 24, (63, 46), lsmash = 0.2816957477760234, random=0.09773125844494625
# round 25, (44, 12), lsmash = 0.16688040572443885, random=0.1410289934189471
# round 26, (71, 88), lsmash = 0.08679725005483181, random=0.047569863684328174
# round 27, (36, 14), lsmash = 0.21340202236505484, random=0.27576037687920496
# round 28, (25, 94), lsmash = 0.729155872080061, random=0.18675317630224478
# round 29, (78, 77), lsmash = 0.12228365095667275, random=0.09049643250204986
# round 30, (38, 78), lsmash = 0.16155833522502425, random=0.04778357824814465
# round 31, (23, 79), lsmash = 0.13948163631577576, random=0.07523471152421177
# round 32, (15, 28), lsmash = 0.5015939873280331, random=0.1451528358326356
# round 33, (57, 85), lsmash = 0.10302532356761036, random=0.0325149338049127
# round 34, (54, 25), lsmash = 0.40661953227155356, random=0.10405887021335848
# round 35, (50, 16), lsmash = 0.674377854903265, random=0.658438306697226
# round 36, (64, 1), lsmash = 0.6276220728530727, random=0.13379889015073435
# round 37, (23, 86), lsmash = 0.3651646975512593, random=0.1011602194859063
# round 38, (67, 61), lsmash = 0.17428617694140358, random=0.3498279136359306
# round 39, (9, 45), lsmash = 0.1554592006210132, random=0.22930258094641123
# round 40, (44, 92), lsmash = 0.13511947066761734, random=0.1271341022162543
# round 41, (64, 14), lsmash = 0.16011929508025927, random=0.15566152715895337
# round 42, (54, 5), lsmash = 0.895993330370191, random=0.7884923980117275
# round 43, (85, 81), lsmash = 0.16386952573513427, random=0.052206086380484816
# round 44, (47, 84), lsmash = 0.46741443775050856, random=0.04821765314337819
# round 45, (64, 28), lsmash = 0.6630927725990385, random=0.07405305954715019
# round 46, (85, 27), lsmash = 0.12094831211923257, random=0.04762647251346523
# round 47, (27, 65), lsmash = 0.2149562180133594, random=0.1989881245893711
# round 48, (29, 63), lsmash = 0.22813523380450598, random=0.41556277940808867
# round 49, (76, 10), lsmash = 0.46867639623822305, random=0.19469560947268247
# round 50, (13, 1), lsmash = 0.47432278849630405, random=0.19613635104852462
# round 51, (95, 88), lsmash = 0.21020646788816844, random=0.07025951791058238
# round 52, (23, 14), lsmash = 0.12963620382251229, random=0.10247199999657114
# round 53, (8, 86), lsmash = 0.15665174212322366, random=0.10692680090163013
# round 54, (16, 69), lsmash = 0.16673055164095676, random=0.06897641111689219
# round 55, (72, 2), lsmash = 0.15854314076662354, random=0.09218564429400314
# round 56, (1, 29), lsmash = 0.44666342408517923, random=0.5476389325836506
# round 57, (64, 7), lsmash = 0.5886331444129347, random=0.2643867113473898
# round 58, (52, 94), lsmash = 0.06949566802340339, random=0.08116138637098816
# round 59, (19, 42), lsmash = 0.3231068046441478, random=0.30097188854156726
# round 60, (54, 24), lsmash = 0.6441633354130216, random=0.19209344490077676
# round 61, (20, 27), lsmash = 0.7885375571845641, random=0.18068672186380283
# round 62, (9, 95), lsmash = 0.5513868622676839, random=0.5853785779967753
# round 63, (95, 26), lsmash = 0.0799161349242476, random=0.08428319754724083
# round 64, (22, 46), lsmash = 0.08170993238205525, random=0.08572986007214914
# round 65, (73, 42), lsmash = 0.31830034073023106, random=0.1596693413513739
# round 66, (24, 74), lsmash = 0.3933802739571881, random=0.4009676486606513
# round 67, (59, 13), lsmash = 0.21673043737265268, random=0.08149021349457167
# round 68, (48, 61), lsmash = 0.08657982892902323, random=0.140033376265791
# round 69, (68, 75), lsmash = 0.1652487910264305, random=0.12865542017404039
# round 70, (54, 48), lsmash = 0.15005725594960936, random=0.21555245623147773
# round 71, (52, 23), lsmash = 0.07442059789157474, random=0.056403173723879645
# round 72, (2, 25), lsmash = 0.15814107357432772, random=0.05729338865167588
# round 73, (63, 49), lsmash = 0.7781859796463911, random=0.14176092445137012
# round 74, (74, 13), lsmash = 0.29448832202062447, random=0.38436036662581874
# round 75, (14, 68), lsmash = 0.19034313152384427, random=0.3084315554130116
# round 76, (20, 37), lsmash = 0.22768804741309476, random=0.10302207399033458
# round 77, (48, 57), lsmash = 0.11734554982036909, random=0.10373674905624602
# round 78, (55, 62), lsmash = 0.07339309460033396, random=0.11227384739653433
# round 79, (84, 14), lsmash = 0.10653857115213007, random=0.10071847927426715
# round 80, (16, 34), lsmash = 0.2734671906315211, random=0.17204117891926154
# round 81, (36, 43), lsmash = 0.2802445567173749, random=0.09644654579757722
# round 82, (42, 58), lsmash = 0.4423049464849549, random=0.41710113840698176
# round 83, (21, 47), lsmash = 0.07191584671910756, random=0.037848187085526716
# round 84, (32, 65), lsmash = 0.47379216461452234, random=0.4400837011391572
# round 85, (63, 64), lsmash = 0.5404223122962526, random=0.16539273711831662
# round 86, (74, 89), lsmash = 0.08492823188461907, random=0.05820687542003755
# round 87, (31, 68), lsmash = 0.21379108665977792, random=0.12029383010219703
# round 88, (43, 26), lsmash = 0.0777288343023996, random=0.05518980795124088
# round 89, (75, 95), lsmash = 0.23930436880316075, random=0.20487247814848372
# round 90, (38, 43), lsmash = 0.3944693528511719, random=0.14035644007134038
# round 91, (97, 23), lsmash = 0.497188186071254, random=0.20867042630460647
# round 92, (82, 33), lsmash = 0.12750565679450684, random=0.17503582454916314
# round 93, (61, 82), lsmash = 0.11308147294605225, random=0.22672147048351446
# round 94, (98, 25), lsmash = 0.12865702734449094, random=0.05351347169006781
# round 95, (100, 52), lsmash = 0.07759234099115425, random=0.07581489886215992
# round 96, (41, 39), lsmash = 0.12184861463752072, random=0.044689300717956196
# round 97, (73, 26), lsmash = 0.09143617123445173, random=0.12009666597348617
# round 98, (52, 81), lsmash = 0.07413227802926094, random=0.05957776112399181
# round 99, (9, 40), lsmash = 0.8265233162726149, random=0.14069163709060709

# %%
plt.figure()
ax = sns.distplot(lsmash_mean_sae, bins=15, label='default')
ax.axvline(np.mean(r_lsmash), color='blue')
sns.distplot(random_mean_sae, bins=15, label='randomly generated (4)')
ax.axvline(np.mean(r_random), color='green')
plt.legend(fontsize=15)
plt.title('SAE Comparison', fontsize=20)
plt.show()
