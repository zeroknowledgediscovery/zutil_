# %%
import pandas as pd
import numpy as np
import pylab as plt
# %matplotlib inline

# %%
df=pd.read_csv('E.dst',sep=" ",header=None).transpose().dropna()

# %%
df1=df.iloc[:,0:4]
df1.columns=['x','y','z','w']
df1=df

# %%
X=df1.values
y=np.zeros([1,115])
y=np.append(y,np.ones([1,90]))
y=np.append(y,2*np.ones([1,262]))

# %%
from sklearn import neighbors, datasets
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

from sklearn.neighbors import KNeighborsClassifier

# %%
CLASSIFIERS=[DecisionTreeClassifier(max_depth=None, min_samples_split=2),
           # RandomForestClassifier(n_estimators=1000, max_depth=None, min_samples_split=2),
           # ExtraTreesClassifier(n_estimators=1000, max_depth=None,
     #min_samples_split=2),
      #      AdaBoostClassifier(n_estimators=1000),
            GradientBoostingClassifier(n_estimators=1000,max_depth=None)]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
for clf in CLASSIFIERS:
    clf.fit(X_train,y_train)
    y_pred=clf.predict_proba(X_test)
    #fpr, tpr, thresholds = metrics.roc_curve(y_test,y_pred[:,1], pos_label=1)
    #auc=metrics.auc(fpr, tpr)
    #print auc
    print accuracy_score(y_test, y_pred[:,1]) 
    #plt.plot(fpr,tpr)
# Out:
# 0.26495726495726496
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-4e912880e09d> in <module>()
#       6     #auc=metrics.auc(fpr, tpr)
#       7     #print auc
# ----> 8     print accuracy_score(y_test, y_pred[:,1])
#       9     #plt.plot(fpr,tpr)
#
# /home/ishanu/.local/lib/python2.7/site-packages/sklearn/metrics/classification.pyc in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# /home/ishanu/.local/lib/python2.7/site-packages/sklearn/metrics/classification.pyc in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
# ...

# %%
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred=neigh.predict(X_test)

# %%
print f1_score(y_test, y_pred,average='weighted')
# Out:
# 0.4382173143730053
